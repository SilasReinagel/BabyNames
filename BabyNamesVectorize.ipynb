# %%
# Install packages
# !pip install chromadb langchain openai beautifulsoup4 langchain-community langchain-openai sentence_transformers -q

# %%
# Import required modules
import chromadb
from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.document_loaders import TextLoader
import requests
import os
import pandas as pd

# %%
# Get OpenAI API key from environment variable
openai_api_key = os.getenv("OPENAI_API_KEY")

if not openai_api_key:
    raise ValueError("Please set the OPENAI_API_KEY environment variable")

# %%
# Setup Langchain and OpenAI Embeddings

from langchain_openai import OpenAIEmbeddings
import os

# Ensure OpenAI API key is set
if "OPENAI_API_KEY" not in os.environ:
    raise ValueError("OPENAI_API_KEY not found in environment variables")

# Initialize OpenAI Embeddings
embed_model = OpenAIEmbeddings(
    model="text-embedding-3-small",
    openai_api_key=os.environ["OPENAI_API_KEY"]
)

# Test the embeddings
test_text = "Hello, world!"
test_embedding = embed_model.embed_query(test_text)

print(f"Embedding dimension: {len(test_embedding)}")
print(f"First 5 values of the embedding: {test_embedding[:5]}")

# Function to get embeddings for a list of texts
def get_embeddings(texts):
    return embed_model.embed_documents(texts)

print("Embeddings setup complete!")
# Out:
# Embedding dimension: 1536
# First 5 values of the embedding: [-0.019184619188308716, -0.025279032066464424, -0.0017195191467180848, 0.01884828321635723, -0.033795066177845]
# Embeddings setup complete!

# %%
# Jupyter Notebook Cell: ChromaDB Initialization

import chromadb
from chromadb.config import Settings
import os

# Set up ChromaDB with a persistent directory
PERSISTENCE_DIRECTORY = "./chroma_db"
os.makedirs(PERSISTENCE_DIRECTORY, exist_ok=True)

# Initialize ChromaDB client with file-based storage
chroma_client = chromadb.PersistentClient(path=PERSISTENCE_DIRECTORY)

# Create or get the 'babynames' collection
collection_name = "babynames"
collection = chroma_client.get_or_create_collection(name=collection_name)

print(f"ChromaDB initialized with persistence directory: {PERSISTENCE_DIRECTORY}")
print(f"Collection '{collection_name}' is ready.")
print(f"Current document count in collection: {collection.count()}")

# Function to get the collection (useful for other cells)
def get_babynames_collection():
    return chroma_client.get_collection(collection_name)

print("\nChromaDB and collection initialization complete!")
# Out:
# ChromaDB initialized with persistence directory: ./chroma_db
# Collection 'babynames' is ready.
# Current document count in collection: 0
#
# ChromaDB and collection initialization complete!

# %%
def format_enriched_baby_names(file='./EnrichedBabyNamesData.csv'):
    # Read the CSV file
    df = pd.read_csv(file)
    
    # Filter rows where meaning is not null/none
    df_filtered = df.dropna(subset=['meaning'])
    
    # Function to format each row
    def format_row(row):
        return f"Name: {row['name']}|Sex: {row['sex']}|Nation: {row['nationality']}|Meaning: {row['meaning']}"
    
    # Apply the formatting function to each row and join the results
    formatted_strings = df_filtered.apply(format_row, axis=1).tolist()
    
    # Join all formatted strings with newlines
    result = '\n'.join(formatted_strings)
    
    print(f"Processed {len(df_filtered)} names with meanings.")
    print("First few formatted entries:")
    print('\n'.join(formatted_strings[:5]))  # Print first 5 entries as a sample
    
    return result

# Example usage
formatted_data = format_enriched_baby_names()
# Out:
# Processed 23007 names with meanings.
# First few formatted entries:
# Name: AARON|Sex: Male|Nation: Hebrew|Meaning: Exalted, high, or mountain of strength
# Name: ABBAS|Sex: Male|Nation: Arabic|Meaning: The name Abbas means 'lion' or 'stern' in Arabic. It is often associated with strength and bravery.
# Name: ABD|Sex: Male|Nation: Arabic|Meaning: The name 'Abd' means 'servant' or 'slave' in Arabic, often used in combination with one of the names of God, such as 'Abdullah' meaning 'servant of God'.
# Name: ABDEL|Sex: Male|Nation: Arabic|Meaning: Servant of God
# Name: ABDUL|Sex: Male|Nation: Arabic|Meaning: Servant of God
# /var/folders/qy/xp_c3ct10h1dpmswk1_51f700000gn/T/ipykernel_57755/821507785.py:3: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)

# %%
import pandas as pd
from tqdm.notebook import tqdm
import chromadb
from chromadb.utils import embedding_functions

def batch_process_baby_names_to_chroma(file='./EnrichedBabyNamesData.csv', batch_size=100):
    # Initialize Chroma client and collection
    embedding_function = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="all-MiniLM-L6-v2")
    collection = get_babynames_collection()

    # Read the CSV file in chunks
    for chunk in tqdm(pd.read_csv(file, chunksize=batch_size), desc="Processing batches"):
        # Filter rows where meaning is not null/none
        chunk_filtered = chunk.dropna(subset=['meaning'])
        
        if chunk_filtered.empty:
            continue
        
        # Format each row
        formatted_data = chunk_filtered.apply(lambda row: f"Name: {row['name']}|Sex: {row['sex']}|Nation: {row['nationality']}|Meaning: {row['meaning']}", axis=1).tolist()
        
        # Use names as IDs
        ids = chunk_filtered['name'].tolist()
        
        # Generate embeddings
        embeddings = embedding_function(formatted_data)
        
        # Prepare metadata
        metadatas = chunk_filtered.to_dict('records')
        
        # Add to Chroma collection
        collection.add(
            ids=ids,
            embeddings=embeddings,
            metadatas=metadatas,
            documents=formatted_data
        )
    
    print(f"Processed and added {collection.count()} baby names to Chroma collection.")

# Example usage
batch_process_baby_names_to_chroma()
# Out:
# Processing batches: 0it [00:00, ?it/s]
# Insert of existing embedding ID: AARON
# Insert of existing embedding ID: ABBAS
# Insert of existing embedding ID: ABD
# Insert of existing embedding ID: ABDEL
# Insert of existing embedding ID: ABDUL
# Insert of existing embedding ID: ABDULKADIR
# Insert of existing embedding ID: ABDULLAH
# Insert of existing embedding ID: ABDULRAHMAN
# Insert of existing embedding ID: ABDURRAHMAN
# Insert of existing embedding ID: ADALBERT
# Insert of existing embedding ID: ADAM
# Insert of existing embedding ID: ADEL
# Insert of existing embedding ID: ADEM
# Insert of existing embedding ID: ADIL
# Insert of existing embedding ID: ADIN
# Insert of existing embedding ID: ADIS
# Insert of existing embedding ID: ADMIR
# Insert of existing embedding ID: ADNAN
# Insert of existing embedding ID: ADOLF
# Insert of existing embedding ID: ADRIAN
# Insert of existing embedding ID: ADRIANO
# Insert of existing embedding ID: AHMED
# Insert of existing embedding ID: AJDIN
# Insert of existing embedding ID: ALAA
# Insert of existing embedding ID: ALAN
# Insert of existing embedding ID: ALBERT
# Insert of existing embedding ID: ALBERTO
# Insert of existing embedding ID: ALBIN
# Insert of existing embedding ID: ALDIN
# Insert of existing embedding ID: ALEJANDRO
# Insert of existing embedding ID: ALEKSA
# Insert of existing embedding ID: ALEN
# Insert of existing embedding ID: ALESSANDRO
# Insert of existing embedding ID: ALEX
# Insert of existing embedding ID: ALEXANDER
# Insert of existing embedding ID: ALEXANDRE
# Insert of existing embedding ID: ALEXANDRU
# Insert of existing embedding ID: ALEXEY
# Insert of existing embedding ID: ALFONS
# Insert of existing embedding ID: ALFRED
# Insert of existing embedding ID: ALI
# Insert of existing embedding ID: ALIREZA
# Insert of existing embedding ID: ALESSIO
# Insert of existing embedding ID: ALMIR
# Insert of existing embedding ID: ALOIS
# Insert of existing embedding ID: ALPER
# Insert of existing embedding ID: ALPEREN
# Insert of existing embedding ID: ALWIN
# Insert of existing embedding ID: AMAR
# Insert of existing embedding ID: AMEL
# Insert of existing embedding ID: AMER
# Insert of existing embedding ID: AMIN
# Insert of existing embedding ID: AMIR
# Insert of existing embedding ID: AMMAR
# Insert of existing embedding ID: ANAS
# Insert of existing embedding ID: ANDI
# Insert of existing embedding ID: ANDRAS
# Insert of existing embedding ID: ANDRE
# Insert of existing embedding ID: ANDREA
# Insert of existing embedding ID: ANDREAS
# Insert of existing embedding ID: ANDREJ
# Insert of existing embedding ID: ANDREW
# Insert of existing embedding ID: ANDREY
# Insert of existing embedding ID: ANDRIJA
# Insert of existing embedding ID: ANDRZEJ
# Insert of existing embedding ID: ANDRÁS
# Insert of existing embedding ID: ANES
# Insert of existing embedding ID: ANGEL
# Insert of existing embedding ID: ANGELO
# Insert of existing embedding ID: ANIL
# Insert of existing embedding ID: ANTE
# Insert of existing embedding ID: ANTHONY
# Insert of existing embedding ID: ANTO
# Insert of existing embedding ID: ANTON
# Insert of existing embedding ID: ANTONI
# Insert of existing embedding ID: ANTONIO
# Insert of existing embedding ID: ARAS
# Insert of existing embedding ID: ARBEN
# Insert of existing embedding ID: ARDA
# Insert of existing embedding ID: ARIAN
# Insert of existing embedding ID: ARIF
# Insert of existing embedding ID: ARKADIUSZ
# Insert of existing embedding ID: ARMAN
# Insert of existing embedding ID: ARMIN
# Insert of existing embedding ID: ARNO
# Insert of existing embedding ID: ARNOLD
# Insert of existing embedding ID: ARTEM
# Insert of existing embedding ID: ARTHUR
# Insert of existing embedding ID: AZAD
# Insert of existing embedding ID: ASHRAF
# Insert of existing embedding ID: ASIM
# Insert of existing embedding ID: ASLAN
# Insert of existing embedding ID: ATTILA
# Insert of existing embedding ID: AUGUST
# Insert of existing embedding ID: AUGUSTIN
# Insert of existing embedding ID: AUREL
# Insert of existing embedding ID: AXEL
# Insert of existing embedding ID: AYDIN
# Insert of existing embedding ID: AYHAN
# Insert of existing embedding ID: AYMAN
# Add of existing embedding ID: AARON
# Add of existing embedding ID: ABBAS
# Add of existing embedding ID: ABD
# Add of existing embedding ID: ABDEL
# Add of existing embedding ID: ABDUL
# Add of existing embedding ID: ABDULKADIR
# Add of existing embedding ID: ABDULLAH
# Add of existing embedding ID: ABDULRAHMAN
# Add of existing embedding ID: ABDURRAHMAN
# Add of existing embedding ID: ADALBERT
# Add of existing embedding ID: ADAM
# Add of existing embedding ID: ADEL
# Add of existing embedding ID: ADEM
# Add of existing embedding ID: ADIL
# Add of existing embedding ID: ADIN
# Add of existing embedding ID: ADIS
# Add of existing embedding ID: ADMIR
# Add of existing embedding ID: ADNAN
# Add of existing embedding ID: ADOLF
# Add of existing embedding ID: ADRIAN
# Add of existing embedding ID: ADRIANO
# Add of existing embedding ID: AHMED
# Add of existing embedding ID: AJDIN
# Add of existing embedding ID: ALAA
# Add of existing embedding ID: ALAN
# Add of existing embedding ID: ALBERT
# Add of existing embedding ID: ALBERTO
# Add of existing embedding ID: ALBIN
# Add of existing embedding ID: ALDIN
# Add of existing embedding ID: ALEJANDRO
# Add of existing embedding ID: ALEKSA
# Add of existing embedding ID: ALEN
# Add of existing embedding ID: ALESSANDRO
# Add of existing embedding ID: ALEX
# Add of existing embedding ID: ALEXANDER
# Add of existing embedding ID: ALEXANDRE
# Add of existing embedding ID: ALEXANDRU
# Add of existing embedding ID: ALEXEY
# Add of existing embedding ID: ALFONS
# Add of existing embedding ID: ALFRED
# Add of existing embedding ID: ALI
# Add of existing embedding ID: ALIREZA
# Add of existing embedding ID: ALESSIO
# Add of existing embedding ID: ALMIR
# Add of existing embedding ID: ALOIS
# Add of existing embedding ID: ALPER
# Add of existing embedding ID: ALPEREN
# Add of existing embedding ID: ALWIN
# Add of existing embedding ID: AMAR
# Add of existing embedding ID: AMEL
# Add of existing embedding ID: AMER
# Add of existing embedding ID: AMIN
# Add of existing embedding ID: AMIR
# Add of existing embedding ID: AMMAR
# Add of existing embedding ID: ANAS
# Add of existing embedding ID: ANDI
# Add of existing embedding ID: ANDRAS
# Add of existing embedding ID: ANDRE
# Add of existing embedding ID: ANDREA
# Add of existing embedding ID: ANDREAS
# Add of existing embedding ID: ANDREJ
# Add of existing embedding ID: ANDREW
# Add of existing embedding ID: ANDREY
# Add of existing embedding ID: ANDRIJA
# Add of existing embedding ID: ANDRZEJ
# Add of existing embedding ID: ANDRÁS
# Add of existing embedding ID: ANES
# Add of existing embedding ID: ANGEL
# Add of existing embedding ID: ANGELO
# Add of existing embedding ID: ANIL
# Add of existing embedding ID: ANTE
# Add of existing embedding ID: ANTHONY
# Add of existing embedding ID: ANTO
# Add of existing embedding ID: ANTON
# Add of existing embedding ID: ANTONI
# Add of existing embedding ID: ANTONIO
# Add of existing embedding ID: ARAS
# Add of existing embedding ID: ARBEN
# Add of existing embedding ID: ARDA
# Add of existing embedding ID: ARIAN
# Add of existing embedding ID: ARIF
# Add of existing embedding ID: ARKADIUSZ
# Add of existing embedding ID: ARMAN
# Add of existing embedding ID: ARMIN
# Add of existing embedding ID: ARNO
# Add of existing embedding ID: ARNOLD
# Add of existing embedding ID: ARTEM
# Add of existing embedding ID: ARTHUR
# Add of existing embedding ID: AZAD
# Add of existing embedding ID: ASHRAF
# Add of existing embedding ID: ASIM
# Add of existing embedding ID: ASLAN
# Add of existing embedding ID: ATTILA
# Add of existing embedding ID: AUGUST
# Add of existing embedding ID: AUGUSTIN
# Add of existing embedding ID: AUREL
# Add of existing embedding ID: AXEL
# Add of existing embedding ID: AYDIN
# Add of existing embedding ID: AYHAN
# Add of existing embedding ID: AYMAN
# Insert of existing embedding ID: AZIZ
# Insert of existing embedding ID: BAJRAM
# Insert of existing embedding ID: BALÁZS
# Insert of existing embedding ID: BARAN
# Insert of existing embedding ID: BARIS
# Insert of existing embedding ID: BARTLOMIEJ
# Insert of existing embedding ID: BARTOSZ
# Insert of existing embedding ID: BASTIAN
# Insert of existing embedding ID: BATUHAN
# Insert of existing embedding ID: BAYRAM
# Insert of existing embedding ID: BEKIM
# Insert of existing embedding ID: BEKIR
# Insert of existing embedding ID: BELA
# Insert of existing embedding ID: BEN
# Insert of existing embedding ID: BENCE
# Insert of existing embedding ID: BENEDIKT
# Insert of existing embedding ID: BENJAMIN
# Insert of existing embedding ID: BENNO
# Insert of existing embedding ID: BERAT
# Insert of existing embedding ID: BERKAY
# Insert of existing embedding ID: BERNARD
# Insert of existing embedding ID: BERNHARD
# Insert of existing embedding ID: BERND
# Insert of existing embedding ID: BERTHOLD
# Insert of existing embedding ID: BEYTULLAH
# Insert of existing embedding ID: BILAL
# Insert of existing embedding ID: BJÖRN
# Insert of existing embedding ID: BOBAN
# Insert of existing embedding ID: BOGDAN
# Insert of existing embedding ID: BOGUSLAW
# Insert of existing embedding ID: BOJAN
# Insert of existing embedding ID: BORIS
# Insert of existing embedding ID: BORISLAV
# Insert of existing embedding ID: BORIVOJE
# Insert of existing embedding ID: BOZIDAR
# Insert of existing embedding ID: BOŽIDAR
# Insert of existing embedding ID: BRANISLAV
# Insert of existing embedding ID: BRANKO
# Insert of existing embedding ID: BRIAN
# Insert of existing embedding ID: BRUNO
# Insert of existing embedding ID: BURAK
# Insert of existing embedding ID: BURHAN
# Insert of existing embedding ID: BÜLENT
# Insert of existing embedding ID: BÜNYAMIN
# Insert of existing embedding ID: CAMILLO
# Insert of existing embedding ID: CAN
# Insert of existing embedding ID: KARL
# Insert of existing embedding ID: CARLOS
# Insert of existing embedding ID: CASPAR
# Insert of existing embedding ID: CEDOMIR
# Insert of existing embedding ID: CELAL
# Insert of existing embedding ID: CEM
# Insert of existing embedding ID: CEMAL
# Insert of existing embedding ID: CEMIL
# Insert of existing embedding ID: CENGIZ
# Insert of existing embedding ID: CHARLES
# Insert of existing embedding ID: CHRISTIAN
# Insert of existing embedding ID: CHRISTOPH
# Insert of existing embedding ID: CHRISTOPHER
# Insert of existing embedding ID: CIHAN
# Insert of existing embedding ID: CLAUDIO
# Insert of existing embedding ID: KLAUS
# Insert of existing embedding ID: CLEMENS
# Insert of existing embedding ID: COLIN
# Insert of existing embedding ID: CSABA
# Insert of existing embedding ID: KIRIL
# Insert of existing embedding ID: DALIBOR
# Insert of existing embedding ID: DAMIAN
# Insert of existing embedding ID: DAMIR
# Insert of existing embedding ID: DAMJAN
# Insert of existing embedding ID: DAN
# Insert of existing embedding ID: DANIEL
# Insert of existing embedding ID: DANILO
# Insert of existing embedding ID: DARIO
# Insert of existing embedding ID: DARIS
# Insert of existing embedding ID: DARIUS
# Insert of existing embedding ID: DARIUSZ
# Insert of existing embedding ID: DARKO
# Insert of existing embedding ID: DAVID
# Insert of existing embedding ID: DAVOR
# Insert of existing embedding ID: DAVUD
# Insert of existing embedding ID: DAVUT
# Insert of existing embedding ID: DEJAN
# Insert of existing embedding ID: DENI
# Insert of existing embedding ID: DENIS
# Insert of existing embedding ID: DIEGO
# Insert of existing embedding ID: DIETER
# Insert of existing embedding ID: DIETMAR
# Insert of existing embedding ID: DIETRICH
# Insert of existing embedding ID: DIMITAR
# Insert of existing embedding ID: DIMITRIJE
# Insert of existing embedding ID: DIMITRIOS
# Insert of existing embedding ID: DINO
# Insert of existing embedding ID: DIRK
# Insert of existing embedding ID: DJORDJE
# Insert of existing embedding ID: DIMITRI
# Insert of existing embedding ID: DMITRY
# Insert of existing embedding ID: DMYTRO
# Insert of existing embedding ID: DOBRICA
# Insert of existing embedding ID: DOGAN
# Add of existing embedding ID: AZIZ
# Add of existing embedding ID: BAJRAM
# Add of existing embedding ID: BALÁZS
# Add of existing embedding ID: BARAN
# Add of existing embedding ID: BARIS
# Add of existing embedding ID: BARTLOMIEJ
# Add of existing embedding ID: BARTOSZ
# Add of existing embedding ID: BASTIAN
# Add of existing embedding ID: BATUHAN
# Add of existing embedding ID: BAYRAM
# Add of existing embedding ID: BEKIM
# Add of existing embedding ID: BEKIR
# Add of existing embedding ID: BELA
# Add of existing embedding ID: BEN
# Add of existing embedding ID: BENCE
# Add of existing embedding ID: BENEDIKT
# Add of existing embedding ID: BENJAMIN
# Add of existing embedding ID: BENNO
# Add of existing embedding ID: BERAT
# Add of existing embedding ID: BERKAY
# Add of existing embedding ID: BERNARD
# Add of existing embedding ID: BERNHARD
# Add of existing embedding ID: BERND
# Add of existing embedding ID: BERTHOLD
# Add of existing embedding ID: BEYTULLAH
# Add of existing embedding ID: BILAL
# Add of existing embedding ID: BJÖRN
# Add of existing embedding ID: BOBAN
# Add of existing embedding ID: BOGDAN
# Add of existing embedding ID: BOGUSLAW
# Add of existing embedding ID: BOJAN
# Add of existing embedding ID: BORIS
# Add of existing embedding ID: BORISLAV
# Add of existing embedding ID: BORIVOJE
# Add of existing embedding ID: BOZIDAR
# Add of existing embedding ID: BOŽIDAR
# Add of existing embedding ID: BRANISLAV
# Add of existing embedding ID: BRANKO
# Add of existing embedding ID: BRIAN
# Add of existing embedding ID: BRUNO
# Add of existing embedding ID: BURAK
# Add of existing embedding ID: BURHAN
# Add of existing embedding ID: BÜLENT
# Add of existing embedding ID: BÜNYAMIN
# Add of existing embedding ID: CAMILLO
# Add of existing embedding ID: CAN
# Add of existing embedding ID: KARL
# Add of existing embedding ID: CARLOS
# Add of existing embedding ID: CASPAR
# Add of existing embedding ID: CEDOMIR
# Add of existing embedding ID: CELAL
# Add of existing embedding ID: CEM
# Add of existing embedding ID: CEMAL
# Add of existing embedding ID: CEMIL
# Add of existing embedding ID: CENGIZ
# Add of existing embedding ID: CHARLES
# Add of existing embedding ID: CHRISTIAN
# Add of existing embedding ID: CHRISTOPH
# Add of existing embedding ID: CHRISTOPHER
# Add of existing embedding ID: CIHAN
# Add of existing embedding ID: CLAUDIO
# Add of existing embedding ID: KLAUS
# Add of existing embedding ID: CLEMENS
# Add of existing embedding ID: COLIN
# Add of existing embedding ID: CSABA
# Add of existing embedding ID: KIRIL
# Add of existing embedding ID: DALIBOR
# Add of existing embedding ID: DAMIAN
# Add of existing embedding ID: DAMIR
# Add of existing embedding ID: DAMJAN
# Add of existing embedding ID: DAN
# Add of existing embedding ID: DANIEL
# Add of existing embedding ID: DANILO
# Add of existing embedding ID: DARIO
# Add of existing embedding ID: DARIS
# Add of existing embedding ID: DARIUS
# Add of existing embedding ID: DARIUSZ
# Add of existing embedding ID: DARKO
# Add of existing embedding ID: DAVID
# Add of existing embedding ID: DAVOR
# Add of existing embedding ID: DAVUD
# Add of existing embedding ID: DAVUT
# Add of existing embedding ID: DEJAN
# Add of existing embedding ID: DENI
# Add of existing embedding ID: DENIS
# Add of existing embedding ID: DIEGO
# Add of existing embedding ID: DIETER
# Add of existing embedding ID: DIETMAR
# Add of existing embedding ID: DIETRICH
# Add of existing embedding ID: DIMITAR
# Add of existing embedding ID: DIMITRIJE
# Add of existing embedding ID: DIMITRIOS
# Add of existing embedding ID: DINO
# Add of existing embedding ID: DIRK
# Add of existing embedding ID: DJORDJE
# Add of existing embedding ID: DIMITRI
# Add of existing embedding ID: DMITRY
# Add of existing embedding ID: DMYTRO
# Add of existing embedding ID: DOBRICA
# Add of existing embedding ID: DOGAN
# Insert of existing embedding ID: DOMINIK
# Insert of existing embedding ID: DORIAN
# Insert of existing embedding ID: DRAGAN
# Insert of existing embedding ID: DRAGISA
# Insert of existing embedding ID: DRAGIŠA
# Insert of existing embedding ID: DRAGO
# Insert of existing embedding ID: DRAGOLJUB
# Insert of existing embedding ID: DRAGOMIR
# Insert of existing embedding ID: DRAGOSLAV
# Insert of existing embedding ID: DRAGUTIN
# Insert of existing embedding ID: DUMITRU
# Insert of existing embedding ID: DURMUS
# Insert of existing embedding ID: DURSUN
# Insert of existing embedding ID: DUSAN
# Insert of existing embedding ID: DUSKO
# Insert of existing embedding ID: DUŠAN
# Insert of existing embedding ID: DUŠKO
# Insert of existing embedding ID: EBERHARD
# Insert of existing embedding ID: EDGAR
# Insert of existing embedding ID: EDIN
# Insert of existing embedding ID: EDIS
# Insert of existing embedding ID: EDMUND
# Insert of existing embedding ID: EDUARD
# Insert of existing embedding ID: EDUARDO
# Insert of existing embedding ID: EDWARD
# Insert of existing embedding ID: EDWIN
# Insert of existing embedding ID: EFE
# Insert of existing embedding ID: EGON
# Insert of existing embedding ID: EKREM
# Insert of existing embedding ID: ELIA
# Insert of existing embedding ID: ELIAS
# Insert of existing embedding ID: ELMAR
# Insert of existing embedding ID: ELVIR
# Insert of existing embedding ID: ELVIS
# Insert of existing embedding ID: EMAD
# Insert of existing embedding ID: EMANUEL
# Insert of existing embedding ID: EMIL
# Insert of existing embedding ID: EMILIAN
# Insert of existing embedding ID: EMILIO
# Insert of existing embedding ID: EMIN
# Insert of existing embedding ID: EMIR
# Insert of existing embedding ID: EMIRHAN
# Insert of existing embedding ID: EMMERICH
# Insert of existing embedding ID: EMRAH
# Insert of existing embedding ID: EMRE
# Insert of existing embedding ID: ENES
# Insert of existing embedding ID: ENGELBERT
# Insert of existing embedding ID: ENGIN
# Insert of existing embedding ID: ENIS
# Insert of existing embedding ID: ENSAR
# Insert of existing embedding ID: ENVER
# Insert of existing embedding ID: ERAY
# Insert of existing embedding ID: ERDAL
# Insert of existing embedding ID: ERDEM
# Insert of existing embedding ID: ERDOGAN
# Insert of existing embedding ID: EREN
# Insert of existing embedding ID: ERHAN
# Insert of existing embedding ID: ERHARD
# Insert of existing embedding ID: ERICH
# Insert of existing embedding ID: ERIK
# Insert of existing embedding ID: ERKAN
# Insert of existing embedding ID: ERNEST
# Insert of existing embedding ID: ERNST
# Insert of existing embedding ID: EROL
# Insert of existing embedding ID: ERSIN
# Insert of existing embedding ID: ERTUGRUL
# Insert of existing embedding ID: ERVIN
# Insert of existing embedding ID: ERWIN
# Insert of existing embedding ID: ESAD
# Insert of existing embedding ID: EUGEN
# Insert of existing embedding ID: EWALD
# Insert of existing embedding ID: EYMEN
# Insert of existing embedding ID: FABIAN
# Insert of existing embedding ID: FABIO
# Insert of existing embedding ID: FADI
# Insert of existing embedding ID: FADIL
# Insert of existing embedding ID: FARID
# Insert of existing embedding ID: FARHAD
# Insert of existing embedding ID: FARUK
# Insert of existing embedding ID: FATIH
# Insert of existing embedding ID: FATMIR
# Insert of existing embedding ID: FERDINAND
# Insert of existing embedding ID: FERENC
# Insert of existing embedding ID: FERHAT
# Insert of existing embedding ID: FERNANDO
# Insert of existing embedding ID: FIKRET
# Insert of existing embedding ID: PHILIPP
# Insert of existing embedding ID: FINN
# Insert of existing embedding ID: FLORENTIN
# Insert of existing embedding ID: FLORIAN
# Insert of existing embedding ID: FLORIN
# Insert of existing embedding ID: FRANCESCO
# Insert of existing embedding ID: FRANCISCO
# Insert of existing embedding ID: FRANJO
# Insert of existing embedding ID: FRANK
# Insert of existing embedding ID: FRANZ
# Insert of existing embedding ID: FREDERIK
# Insert of existing embedding ID: FRIDOLIN
# Add of existing embedding ID: DOMINIK
# Add of existing embedding ID: DORIAN
# Add of existing embedding ID: DRAGAN
# Add of existing embedding ID: DRAGISA
# Add of existing embedding ID: DRAGIŠA
# Add of existing embedding ID: DRAGO
# Add of existing embedding ID: DRAGOLJUB
# Add of existing embedding ID: DRAGOMIR
# Add of existing embedding ID: DRAGOSLAV
# Add of existing embedding ID: DRAGUTIN
# Add of existing embedding ID: DUMITRU
# Add of existing embedding ID: DURMUS
# Add of existing embedding ID: DURSUN
# Add of existing embedding ID: DUSAN
# Add of existing embedding ID: DUSKO
# Add of existing embedding ID: DUŠAN
# Add of existing embedding ID: DUŠKO
# Add of existing embedding ID: EBERHARD
# Add of existing embedding ID: EDGAR
# Add of existing embedding ID: EDIN
# Add of existing embedding ID: EDIS
# Add of existing embedding ID: EDMUND
# Add of existing embedding ID: EDUARD
# Add of existing embedding ID: EDUARDO
# Add of existing embedding ID: EDWARD
# Add of existing embedding ID: EDWIN
# Add of existing embedding ID: EFE
# Add of existing embedding ID: EGON
# Add of existing embedding ID: EKREM
# Add of existing embedding ID: ELIA
# Add of existing embedding ID: ELIAS
# Add of existing embedding ID: ELMAR
# Add of existing embedding ID: ELVIR
# Add of existing embedding ID: ELVIS
# Add of existing embedding ID: EMAD
# Add of existing embedding ID: EMANUEL
# Add of existing embedding ID: EMIL
# Add of existing embedding ID: EMILIAN
# Add of existing embedding ID: EMILIO
# Add of existing embedding ID: EMIN
# Add of existing embedding ID: EMIR
# Add of existing embedding ID: EMIRHAN
# Add of existing embedding ID: EMMERICH
# Add of existing embedding ID: EMRAH
# Add of existing embedding ID: EMRE
# Add of existing embedding ID: ENES
# Add of existing embedding ID: ENGELBERT
# Add of existing embedding ID: ENGIN
# Add of existing embedding ID: ENIS
# Add of existing embedding ID: ENSAR
# Add of existing embedding ID: ENVER
# Add of existing embedding ID: ERAY
# Add of existing embedding ID: ERDAL
# Add of existing embedding ID: ERDEM
# Add of existing embedding ID: ERDOGAN
# Add of existing embedding ID: EREN
# Add of existing embedding ID: ERHAN
# Add of existing embedding ID: ERHARD
# Add of existing embedding ID: ERICH
# Add of existing embedding ID: ERIK
# Add of existing embedding ID: ERKAN
# Add of existing embedding ID: ERNEST
# Add of existing embedding ID: ERNST
# Add of existing embedding ID: EROL
# Add of existing embedding ID: ERSIN
# Add of existing embedding ID: ERTUGRUL
# Add of existing embedding ID: ERVIN
# Add of existing embedding ID: ERWIN
# Add of existing embedding ID: ESAD
# Add of existing embedding ID: EUGEN
# Add of existing embedding ID: EWALD
# Add of existing embedding ID: EYMEN
# Add of existing embedding ID: FABIAN
# Add of existing embedding ID: FABIO
# Add of existing embedding ID: FADI
# Add of existing embedding ID: FADIL
# Add of existing embedding ID: FARID
# Add of existing embedding ID: FARHAD
# Add of existing embedding ID: FARUK
# Add of existing embedding ID: FATIH
# Add of existing embedding ID: FATMIR
# Add of existing embedding ID: FERDINAND
# Add of existing embedding ID: FERENC
# Add of existing embedding ID: FERHAT
# Add of existing embedding ID: FERNANDO
# Add of existing embedding ID: FIKRET
# Add of existing embedding ID: PHILIPP
# Add of existing embedding ID: FINN
# Add of existing embedding ID: FLORENTIN
# Add of existing embedding ID: FLORIAN
# Add of existing embedding ID: FLORIN
# Add of existing embedding ID: FRANCESCO
# Add of existing embedding ID: FRANCISCO
# Add of existing embedding ID: FRANJO
# Add of existing embedding ID: FRANK
# Add of existing embedding ID: FRANZ
# Add of existing embedding ID: FREDERIK
# Add of existing embedding ID: FRIDOLIN
# Insert of existing embedding ID: FRIEDRICH
# Insert of existing embedding ID: FRITZ
# Insert of existing embedding ID: FURKAN
# Insert of existing embedding ID: GABOR
# Insert of existing embedding ID: GABRIEL
# Insert of existing embedding ID: GEORG
# Insert of existing embedding ID: GEORGE
# Insert of existing embedding ID: GEORGI
# Insert of existing embedding ID: GEORGIOS
# Insert of existing embedding ID: GERALD
# Insert of existing embedding ID: GERGELY
# Insert of existing embedding ID: GERHARD
# Insert of existing embedding ID: GERHART
# Insert of existing embedding ID: GERNOT
# Insert of existing embedding ID: GEROLD
# Insert of existing embedding ID: GERD
# Insert of existing embedding ID: GHEORGHE
# Insert of existing embedding ID: GILBERT
# Insert of existing embedding ID: GIOVANNI
# Insert of existing embedding ID: GIUSEPPE
# Insert of existing embedding ID: GORAN
# Insert of existing embedding ID: GOTTFRIED
# Insert of existing embedding ID: GREGOR
# Insert of existing embedding ID: GRZEGORZ
# Insert of existing embedding ID: GUENTER
# Insert of existing embedding ID: GUENTHER
# Insert of existing embedding ID: GUIDO
# Insert of existing embedding ID: GUNTHER
# Insert of existing embedding ID: GUSTAV
# Insert of existing embedding ID: GYULA
# Insert of existing embedding ID: GYÖRGY
# Insert of existing embedding ID: GÁBOR
# Insert of existing embedding ID: GÖKHAN
# Insert of existing embedding ID: GÜNTER
# Insert of existing embedding ID: HABIB
# Insert of existing embedding ID: HACI
# Insert of existing embedding ID: HADI
# Insert of existing embedding ID: HAKAN
# Insert of existing embedding ID: HALIL
# Insert of existing embedding ID: HALIT
# Insert of existing embedding ID: HAMDI
# Insert of existing embedding ID: HAMID
# Insert of existing embedding ID: HAMZA
# Insert of existing embedding ID: HANI
# Insert of existing embedding ID: HANNES
# Insert of existing embedding ID: HANS
# Insert of existing embedding ID: HANSJÖRG
# Insert of existing embedding ID: HANS-PETER
# Insert of existing embedding ID: HARALD
# Insert of existing embedding ID: HARIS
# Insert of existing embedding ID: HARRY
# Insert of existing embedding ID: HARTMUT
# Insert of existing embedding ID: HARUN
# Insert of existing embedding ID: HASAN
# Insert of existing embedding ID: HAYDAR
# Insert of existing embedding ID: HEIMO
# Insert of existing embedding ID: HEINRICH
# Insert of existing embedding ID: HEINZ
# Insert of existing embedding ID: HELMUT
# Insert of existing embedding ID: HENRIK
# Insert of existing embedding ID: HENRY
# Insert of existing embedding ID: HERBERT
# Insert of existing embedding ID: HERIBERT
# Insert of existing embedding ID: HERMANN
# Insert of existing embedding ID: HERWIG
# Insert of existing embedding ID: HOLGER
# Insert of existing embedding ID: HORST
# Insert of existing embedding ID: HOSSEIN
# Insert of existing embedding ID: HRISTO
# Insert of existing embedding ID: HUBERT
# Insert of existing embedding ID: HUGO
# Insert of existing embedding ID: HÜSEYIN
# Insert of existing embedding ID: IAN
# Insert of existing embedding ID: IBRAHIM
# Insert of existing embedding ID: IDRIS
# Insert of existing embedding ID: IGNAZ
# Insert of existing embedding ID: IGOR
# Insert of existing embedding ID: ILHAN
# Insert of existing embedding ID: ILYAS
# Insert of existing embedding ID: ILIE
# Insert of existing embedding ID: ILIJA
# Insert of existing embedding ID: IMRAN
# Insert of existing embedding ID: IMRE
# Insert of existing embedding ID: INGO
# Insert of existing embedding ID: IOAN
# Insert of existing embedding ID: IOANNIS
# Insert of existing embedding ID: ION
# Insert of existing embedding ID: IONUT
# Insert of existing embedding ID: IRFAN
# Insert of existing embedding ID: ISA
# Insert of existing embedding ID: ISAAC
# Insert of existing embedding ID: ISLAM
# Insert of existing embedding ID: ISMAIL
# Insert of existing embedding ID: ISMET
# Insert of existing embedding ID: ISTVÁN
# Insert of existing embedding ID: IVAN
# Insert of existing embedding ID: IVICA
# Insert of existing embedding ID: IVO
# Insert of existing embedding ID: IZET
# Insert of existing embedding ID: JACEK
# Add of existing embedding ID: FRIEDRICH
# Add of existing embedding ID: FRITZ
# Add of existing embedding ID: FURKAN
# Add of existing embedding ID: GABOR
# Add of existing embedding ID: GABRIEL
# Add of existing embedding ID: GEORG
# Add of existing embedding ID: GEORGE
# Add of existing embedding ID: GEORGI
# Add of existing embedding ID: GEORGIOS
# Add of existing embedding ID: GERALD
# Add of existing embedding ID: GERGELY
# Add of existing embedding ID: GERHARD
# Add of existing embedding ID: GERHART
# Add of existing embedding ID: GERNOT
# Add of existing embedding ID: GEROLD
# Add of existing embedding ID: GERD
# Add of existing embedding ID: GHEORGHE
# Add of existing embedding ID: GILBERT
# Add of existing embedding ID: GIOVANNI
# Add of existing embedding ID: GIUSEPPE
# Add of existing embedding ID: GORAN
# Add of existing embedding ID: GOTTFRIED
# Add of existing embedding ID: GREGOR
# Add of existing embedding ID: GRZEGORZ
# Add of existing embedding ID: GUENTER
# Add of existing embedding ID: GUENTHER
# Add of existing embedding ID: GUIDO
# Add of existing embedding ID: GUNTHER
# Add of existing embedding ID: GUSTAV
# Add of existing embedding ID: GYULA
# Add of existing embedding ID: GYÖRGY
# Add of existing embedding ID: GÁBOR
# Add of existing embedding ID: GÖKHAN
# Add of existing embedding ID: GÜNTER
# Add of existing embedding ID: HABIB
# Add of existing embedding ID: HACI
# Add of existing embedding ID: HADI
# Add of existing embedding ID: HAKAN
# Add of existing embedding ID: HALIL
# Add of existing embedding ID: HALIT
# Add of existing embedding ID: HAMDI
# Add of existing embedding ID: HAMID
# Add of existing embedding ID: HAMZA
# Add of existing embedding ID: HANI
# Add of existing embedding ID: HANNES
# Add of existing embedding ID: HANS
# Add of existing embedding ID: HANSJÖRG
# Add of existing embedding ID: HANS-PETER
# Add of existing embedding ID: HARALD
# Add of existing embedding ID: HARIS
# Add of existing embedding ID: HARRY
# Add of existing embedding ID: HARTMUT
# Add of existing embedding ID: HARUN
# Add of existing embedding ID: HASAN
# Add of existing embedding ID: HAYDAR
# Add of existing embedding ID: HEIMO
# Add of existing embedding ID: HEINRICH
# Add of existing embedding ID: HEINZ
# Add of existing embedding ID: HELMUT
# Add of existing embedding ID: HENRIK
# Add of existing embedding ID: HENRY
# Add of existing embedding ID: HERBERT
# Add of existing embedding ID: HERIBERT
# Add of existing embedding ID: HERMANN
# Add of existing embedding ID: HERWIG
# Add of existing embedding ID: HOLGER
# Add of existing embedding ID: HORST
# Add of existing embedding ID: HOSSEIN
# Add of existing embedding ID: HRISTO
# Add of existing embedding ID: HUBERT
# Add of existing embedding ID: HUGO
# Add of existing embedding ID: HÜSEYIN
# Add of existing embedding ID: IAN
# Add of existing embedding ID: IBRAHIM
# Add of existing embedding ID: IDRIS
# Add of existing embedding ID: IGNAZ
# Add of existing embedding ID: IGOR
# Add of existing embedding ID: ILHAN
# Add of existing embedding ID: ILYAS
# Add of existing embedding ID: ILIE
# Add of existing embedding ID: ILIJA
# Add of existing embedding ID: IMRAN
# Add of existing embedding ID: IMRE
# Add of existing embedding ID: INGO
# Add of existing embedding ID: IOAN
# Add of existing embedding ID: IOANNIS
# Add of existing embedding ID: ION
# Add of existing embedding ID: IONUT
# Add of existing embedding ID: IRFAN
# Add of existing embedding ID: ISA
# Add of existing embedding ID: ISAAC
# Add of existing embedding ID: ISLAM
# Add of existing embedding ID: ISMAIL
# Add of existing embedding ID: ISMET
# Add of existing embedding ID: ISTVÁN
# Add of existing embedding ID: IVAN
# Add of existing embedding ID: IVICA
# Add of existing embedding ID: IVO
# Add of existing embedding ID: IZET
# Add of existing embedding ID: JACEK
# Insert of existing embedding ID: JAKOB
# Insert of existing embedding ID: JAKOV
# Insert of existing embedding ID: JAKUB
# Insert of existing embedding ID: JAMAL
# Insert of existing embedding ID: JAMES
# Insert of existing embedding ID: JAMIE
# Insert of existing embedding ID: JAN
# Insert of existing embedding ID: YANNICK
# Insert of existing embedding ID: JANIS
# Insert of existing embedding ID: JÁNOS
# Insert of existing embedding ID: JANUSZ
# Insert of existing embedding ID: JAROSLAV
# Insert of existing embedding ID: JAROSLAW
# Insert of existing embedding ID: JASMIN
# Insert of existing embedding ID: JASON
# Insert of existing embedding ID: JEAN
# Insert of existing embedding ID: JENS
# Insert of existing embedding ID: JEREMY
# Insert of existing embedding ID: JERZY
# Insert of existing embedding ID: JIRI
# Insert of existing embedding ID: JOACHIM
# Insert of existing embedding ID: JOCHEN
# Insert of existing embedding ID: JOEL
# Insert of existing embedding ID: JOHANN
# Insert of existing embedding ID: JOHANNES
# Insert of existing embedding ID: JOHN
# Insert of existing embedding ID: JONA
# Insert of existing embedding ID: JONAS
# Insert of existing embedding ID: JONATHAN
# Insert of existing embedding ID: JORGE
# Insert of existing embedding ID: JOSEF
# Insert of existing embedding ID: JOSHUA
# Insert of existing embedding ID: JOSIP
# Insert of existing embedding ID: JOSE
# Insert of existing embedding ID: JOVAN
# Insert of existing embedding ID: JOVICA
# Insert of existing embedding ID: JOZO
# Insert of existing embedding ID: JOZSEF
# Insert of existing embedding ID: JUAN
# Insert of existing embedding ID: JUERGEN
# Insert of existing embedding ID: JULIAN
# Insert of existing embedding ID: JULIUS
# Insert of existing embedding ID: JURAJ
# Insert of existing embedding ID: JURI
# Insert of existing embedding ID: JUSTIN
# Insert of existing embedding ID: JÁN
# Insert of existing embedding ID: JÓZEF
# Insert of existing embedding ID: JÓZSEF
# Insert of existing embedding ID: JÖRG
# Insert of existing embedding ID: JÜRGEN
# Insert of existing embedding ID: KAAN
# Insert of existing embedding ID: KACPER
# Insert of existing embedding ID: KADIR
# Insert of existing embedding ID: KAI
# Insert of existing embedding ID: KAMAL
# Insert of existing embedding ID: KAMIL
# Insert of existing embedding ID: KARIM
# Insert of existing embedding ID: KARL-HEINZ
# Insert of existing embedding ID: CARLO
# Insert of existing embedding ID: KAROL
# Insert of existing embedding ID: CARSTEN
# Insert of existing embedding ID: KAZIM
# Insert of existing embedding ID: KAZIMIERZ
# Insert of existing embedding ID: KEMAL
# Insert of existing embedding ID: KENAN
# Insert of existing embedding ID: KEREM
# Insert of existing embedding ID: KERIM
# Insert of existing embedding ID: KEVIN
# Insert of existing embedding ID: KHALED
# Insert of existing embedding ID: KHALIL
# Insert of existing embedding ID: KIAN
# Insert of existing embedding ID: KILIAN
# Insert of existing embedding ID: KONRAD
# Insert of existing embedding ID: KONSTANTIN
# Insert of existing embedding ID: KONSTANTINOS
# Insert of existing embedding ID: CORNEL
# Insert of existing embedding ID: CORNELIUS
# Insert of existing embedding ID: KOSTA
# Insert of existing embedding ID: KRISZTIÁN
# Insert of existing embedding ID: KRZYSZTOF
# Insert of existing embedding ID: KURT
# Insert of existing embedding ID: LADISLAUS
# Insert of existing embedding ID: LADISLAV
# Insert of existing embedding ID: LAJOS
# Insert of existing embedding ID: LARS
# Insert of existing embedding ID: LASZLO
# Insert of existing embedding ID: LAURENZ
# Insert of existing embedding ID: LAURIN
# Insert of existing embedding ID: LAZAR
# Insert of existing embedding ID: LEANDER
# Insert of existing embedding ID: LEANDRO
# Insert of existing embedding ID: LENNART
# Insert of existing embedding ID: LEO
# Insert of existing embedding ID: LEON
# Insert of existing embedding ID: LEONARD
# Insert of existing embedding ID: LEONARDO
# Insert of existing embedding ID: LEONID
# Insert of existing embedding ID: LEOPOLD
# Insert of existing embedding ID: LESZEK
# Insert of existing embedding ID: LEVENT
# Add of existing embedding ID: JAKOB
# Add of existing embedding ID: JAKOV
# Add of existing embedding ID: JAKUB
# Add of existing embedding ID: JAMAL
# Add of existing embedding ID: JAMES
# Add of existing embedding ID: JAMIE
# Add of existing embedding ID: JAN
# Add of existing embedding ID: YANNICK
# Add of existing embedding ID: JANIS
# Add of existing embedding ID: JÁNOS
# Add of existing embedding ID: JANUSZ
# Add of existing embedding ID: JAROSLAV
# Add of existing embedding ID: JAROSLAW
# Add of existing embedding ID: JASMIN
# Add of existing embedding ID: JASON
# Add of existing embedding ID: JEAN
# Add of existing embedding ID: JENS
# Add of existing embedding ID: JEREMY
# Add of existing embedding ID: JERZY
# Add of existing embedding ID: JIRI
# Add of existing embedding ID: JOACHIM
# Add of existing embedding ID: JOCHEN
# Add of existing embedding ID: JOEL
# Add of existing embedding ID: JOHANN
# Add of existing embedding ID: JOHANNES
# Add of existing embedding ID: JOHN
# Add of existing embedding ID: JONA
# Add of existing embedding ID: JONAS
# Add of existing embedding ID: JONATHAN
# Add of existing embedding ID: JORGE
# Add of existing embedding ID: JOSEF
# Add of existing embedding ID: JOSHUA
# Add of existing embedding ID: JOSIP
# Add of existing embedding ID: JOSE
# Add of existing embedding ID: JOVAN
# Add of existing embedding ID: JOVICA
# Add of existing embedding ID: JOZO
# Add of existing embedding ID: JOZSEF
# Add of existing embedding ID: JUAN
# Add of existing embedding ID: JUERGEN
# Add of existing embedding ID: JULIAN
# Add of existing embedding ID: JULIUS
# Add of existing embedding ID: JURAJ
# Add of existing embedding ID: JURI
# Add of existing embedding ID: JUSTIN
# Add of existing embedding ID: JÁN
# Add of existing embedding ID: JÓZEF
# Add of existing embedding ID: JÓZSEF
# Add of existing embedding ID: JÖRG
# Add of existing embedding ID: JÜRGEN
# Add of existing embedding ID: KAAN
# Add of existing embedding ID: KACPER
# Add of existing embedding ID: KADIR
# Add of existing embedding ID: KAI
# Add of existing embedding ID: KAMAL
# Add of existing embedding ID: KAMIL
# Add of existing embedding ID: KARIM
# Add of existing embedding ID: KARL-HEINZ
# Add of existing embedding ID: CARLO
# Add of existing embedding ID: KAROL
# Add of existing embedding ID: CARSTEN
# Add of existing embedding ID: KAZIM
# Add of existing embedding ID: KAZIMIERZ
# Add of existing embedding ID: KEMAL
# Add of existing embedding ID: KENAN
# Add of existing embedding ID: KEREM
# Add of existing embedding ID: KERIM
# Add of existing embedding ID: KEVIN
# Add of existing embedding ID: KHALED
# Add of existing embedding ID: KHALIL
# Add of existing embedding ID: KIAN
# Add of existing embedding ID: KILIAN
# Add of existing embedding ID: KONRAD
# Add of existing embedding ID: KONSTANTIN
# Add of existing embedding ID: KONSTANTINOS
# Add of existing embedding ID: CORNEL
# Add of existing embedding ID: CORNELIUS
# Add of existing embedding ID: KOSTA
# Add of existing embedding ID: KRISZTIÁN
# Add of existing embedding ID: KRZYSZTOF
# Add of existing embedding ID: KURT
# Add of existing embedding ID: LADISLAUS
# Add of existing embedding ID: LADISLAV
# Add of existing embedding ID: LAJOS
# Add of existing embedding ID: LARS
# Add of existing embedding ID: LASZLO
# Add of existing embedding ID: LAURENZ
# Add of existing embedding ID: LAURIN
# Add of existing embedding ID: LAZAR
# Add of existing embedding ID: LEANDER
# Add of existing embedding ID: LEANDRO
# Add of existing embedding ID: LENNART
# Add of existing embedding ID: LEO
# Add of existing embedding ID: LEON
# Add of existing embedding ID: LEONARD
# Add of existing embedding ID: LEONARDO
# Add of existing embedding ID: LEONID
# Add of existing embedding ID: LEOPOLD
# Add of existing embedding ID: LESZEK
# Add of existing embedding ID: LEVENT
# Insert of existing embedding ID: LEVENTE
# Insert of existing embedding ID: LEVI
# Insert of existing embedding ID: LEVIN
# Insert of existing embedding ID: LIAM
# Insert of existing embedding ID: LINUS
# Insert of existing embedding ID: LIONEL
# Insert of existing embedding ID: LJUBISA
# Insert of existing embedding ID: LJUBIŠA
# Insert of existing embedding ID: LJUBOMIR
# Insert of existing embedding ID: LORENZ
# Insert of existing embedding ID: LORENZO
# Insert of existing embedding ID: LOTHAR
# Insert of existing embedding ID: LUDWIG
# Insert of existing embedding ID: LUIS
# Insert of existing embedding ID: LUCA
# Insert of existing embedding ID: LUKAS
# Insert of existing embedding ID: LUCIAN
# Insert of existing embedding ID: LÁSZLÓ
# Insert of existing embedding ID: MACIEJ
# Insert of existing embedding ID: MAGOMED
# Insert of existing embedding ID: MAHDI
# Insert of existing embedding ID: MAHER
# Insert of existing embedding ID: MAHIR
# Insert of existing embedding ID: MAHMOUD
# Insert of existing embedding ID: MAJID
# Insert of existing embedding ID: MAXIM
# Insert of existing embedding ID: MALIK
# Insert of existing embedding ID: MANFRED
# Insert of existing embedding ID: MANSUR
# Insert of existing embedding ID: MANUEL
# Insert of existing embedding ID: MARCEL
# Insert of existing embedding ID: MARCELL
# Insert of existing embedding ID: MARCELLO
# Insert of existing embedding ID: MARCIN
# Insert of existing embedding ID: MAREK
# Insert of existing embedding ID: MARIAN
# Insert of existing embedding ID: MARIN
# Insert of existing embedding ID: MARINKO
# Insert of existing embedding ID: MARIO
# Insert of existing embedding ID: MARIUS
# Insert of existing embedding ID: MARIUSZ
# Insert of existing embedding ID: MARC
# Insert of existing embedding ID: MARKO
# Insert of existing embedding ID: MARKUS
# Insert of existing embedding ID: MARLON
# Insert of existing embedding ID: MARTIN
# Insert of existing embedding ID: MARVIN
# Insert of existing embedding ID: MATEJ
# Insert of existing embedding ID: MATEJA
# Insert of existing embedding ID: MATEUSZ
# Insert of existing embedding ID: MATIJA
# Insert of existing embedding ID: MATO
# Insert of existing embedding ID: MATTEO
# Insert of existing embedding ID: MATTHEW
# Insert of existing embedding ID: MATTHIAS
# Insert of existing embedding ID: MATTHÄUS
# Insert of existing embedding ID: MAURICE
# Insert of existing embedding ID: MAURIZIO
# Insert of existing embedding ID: MAX
# Insert of existing embedding ID: MAXIMILIAN
# Insert of existing embedding ID: MEHDI
# Insert of existing embedding ID: MEHMET
# Insert of existing embedding ID: MELIH
# Insert of existing embedding ID: MERT
# Insert of existing embedding ID: MESUT
# Insert of existing embedding ID: METIN
# Insert of existing embedding ID: MHD
# Insert of existing embedding ID: MICHAEL
# Insert of existing embedding ID: MICHAL
# Insert of existing embedding ID: MICHELE
# Insert of existing embedding ID: MICHELLE
# Insert of existing embedding ID: MIECZYSLAW
# Insert of existing embedding ID: MIGUEL
# Insert of existing embedding ID: MIHAEL
# Insert of existing embedding ID: MIHAI
# Insert of existing embedding ID: MIHAIL
# Insert of existing embedding ID: MIHAJLO
# Insert of existing embedding ID: MIJO
# Insert of existing embedding ID: MIKA
# Insert of existing embedding ID: MIKAIL
# Insert of existing embedding ID: MIKE
# Insert of existing embedding ID: MILAD
# Insert of existing embedding ID: MILADIN
# Insert of existing embedding ID: MILAN
# Insert of existing embedding ID: MILE
# Insert of existing embedding ID: MILENKO
# Insert of existing embedding ID: MILIVOJE
# Insert of existing embedding ID: MILOMIR
# Insert of existing embedding ID: MILORAD
# Insert of existing embedding ID: MILOVAN
# Insert of existing embedding ID: MILOŠ
# Insert of existing embedding ID: MILUTIN
# Insert of existing embedding ID: MIODRAG
# Insert of existing embedding ID: MIRAÇ
# Insert of existing embedding ID: MIRKO
# Insert of existing embedding ID: MIROLJUB
# Insert of existing embedding ID: MIROSLAV
# Insert of existing embedding ID: MIROSLAW
# Insert of existing embedding ID: MIRSAD
# Insert of existing embedding ID: MIRZA
# Add of existing embedding ID: LEVENTE
# Add of existing embedding ID: LEVI
# Add of existing embedding ID: LEVIN
# Add of existing embedding ID: LIAM
# Add of existing embedding ID: LINUS
# Add of existing embedding ID: LIONEL
# Add of existing embedding ID: LJUBISA
# Add of existing embedding ID: LJUBIŠA
# Add of existing embedding ID: LJUBOMIR
# Add of existing embedding ID: LORENZ
# Add of existing embedding ID: LORENZO
# Add of existing embedding ID: LOTHAR
# Add of existing embedding ID: LUDWIG
# Add of existing embedding ID: LUIS
# Add of existing embedding ID: LUCA
# Add of existing embedding ID: LUKAS
# Add of existing embedding ID: LUCIAN
# Add of existing embedding ID: LÁSZLÓ
# Add of existing embedding ID: MACIEJ
# Add of existing embedding ID: MAGOMED
# Add of existing embedding ID: MAHDI
# Add of existing embedding ID: MAHER
# Add of existing embedding ID: MAHIR
# Add of existing embedding ID: MAHMOUD
# Add of existing embedding ID: MAJID
# Add of existing embedding ID: MAXIM
# Add of existing embedding ID: MALIK
# Add of existing embedding ID: MANFRED
# Add of existing embedding ID: MANSUR
# Add of existing embedding ID: MANUEL
# Add of existing embedding ID: MARCEL
# Add of existing embedding ID: MARCELL
# Add of existing embedding ID: MARCELLO
# Add of existing embedding ID: MARCIN
# Add of existing embedding ID: MAREK
# Add of existing embedding ID: MARIAN
# Add of existing embedding ID: MARIN
# Add of existing embedding ID: MARINKO
# Add of existing embedding ID: MARIO
# Add of existing embedding ID: MARIUS
# Add of existing embedding ID: MARIUSZ
# Add of existing embedding ID: MARC
# Add of existing embedding ID: MARKO
# Add of existing embedding ID: MARKUS
# Add of existing embedding ID: MARLON
# Add of existing embedding ID: MARTIN
# Add of existing embedding ID: MARVIN
# Add of existing embedding ID: MATEJ
# Add of existing embedding ID: MATEJA
# Add of existing embedding ID: MATEUSZ
# Add of existing embedding ID: MATIJA
# Add of existing embedding ID: MATO
# Add of existing embedding ID: MATTEO
# Add of existing embedding ID: MATTHEW
# Add of existing embedding ID: MATTHIAS
# Add of existing embedding ID: MATTHÄUS
# Add of existing embedding ID: MAURICE
# Add of existing embedding ID: MAURIZIO
# Add of existing embedding ID: MAX
# Add of existing embedding ID: MAXIMILIAN
# Add of existing embedding ID: MEHDI
# Add of existing embedding ID: MEHMET
# Add of existing embedding ID: MELIH
# Add of existing embedding ID: MERT
# Add of existing embedding ID: MESUT
# Add of existing embedding ID: METIN
# Add of existing embedding ID: MHD
# Add of existing embedding ID: MICHAEL
# Add of existing embedding ID: MICHAL
# Add of existing embedding ID: MICHELE
# Add of existing embedding ID: MICHELLE
# Add of existing embedding ID: MIECZYSLAW
# Add of existing embedding ID: MIGUEL
# Add of existing embedding ID: MIHAEL
# Add of existing embedding ID: MIHAI
# Add of existing embedding ID: MIHAIL
# Add of existing embedding ID: MIHAJLO
# Add of existing embedding ID: MIJO
# Add of existing embedding ID: MIKA
# Add of existing embedding ID: MIKAIL
# Add of existing embedding ID: MIKE
# Add of existing embedding ID: MILAD
# Add of existing embedding ID: MILADIN
# Add of existing embedding ID: MILAN
# Add of existing embedding ID: MILE
# Add of existing embedding ID: MILENKO
# Add of existing embedding ID: MILIVOJE
# Add of existing embedding ID: MILOMIR
# Add of existing embedding ID: MILORAD
# Add of existing embedding ID: MILOVAN
# Add of existing embedding ID: MILOŠ
# Add of existing embedding ID: MILUTIN
# Add of existing embedding ID: MIODRAG
# Add of existing embedding ID: MIRAÇ
# Add of existing embedding ID: MIRKO
# Add of existing embedding ID: MIROLJUB
# Add of existing embedding ID: MIROSLAV
# Add of existing embedding ID: MIROSLAW
# Add of existing embedding ID: MIRSAD
# Add of existing embedding ID: MIRZA
# Insert of existing embedding ID: MLADEN
# Insert of existing embedding ID: MOHSEN
# Insert of existing embedding ID: MOMCILO
# Insert of existing embedding ID: MORITZ
# Insert of existing embedding ID: MOUSTAFA
# Insert of existing embedding ID: MUAMMER
# Insert of existing embedding ID: MOHAMMAD
# Insert of existing embedding ID: MUHARREM
# Insert of existing embedding ID: MURAT
# Insert of existing embedding ID: MUSA
# Insert of existing embedding ID: MUSAB
# Insert of existing embedding ID: MUSTAFA
# Insert of existing embedding ID: MUZAFFER
# Insert of existing embedding ID: NABIL
# Insert of existing embedding ID: NASER
# Insert of existing embedding ID: NATHAN
# Insert of existing embedding ID: NAVID
# Insert of existing embedding ID: NEBOJSA
# Insert of existing embedding ID: NEBOJŠA
# Insert of existing embedding ID: NECATI
# Insert of existing embedding ID: NEDELJKO
# Insert of existing embedding ID: NEDIM
# Insert of existing embedding ID: NEMANJA
# Insert of existing embedding ID: NENAD
# Insert of existing embedding ID: NERMIN
# Insert of existing embedding ID: NICO
# Insert of existing embedding ID: NICOLAE
# Insert of existing embedding ID: NICOLAS
# Insert of existing embedding ID: NIHAD
# Insert of existing embedding ID: NIHAT
# Insert of existing embedding ID: NICK
# Insert of existing embedding ID: NIKITA
# Insert of existing embedding ID: NIKLAS
# Insert of existing embedding ID: NIKOLA
# Insert of existing embedding ID: NIKOLAOS
# Insert of existing embedding ID: NIKOLAUS
# Insert of existing embedding ID: NIKOLAY
# Insert of existing embedding ID: NILS
# Insert of existing embedding ID: NINO
# Insert of existing embedding ID: NOAH
# Insert of existing embedding ID: NOEL
# Insert of existing embedding ID: NORBERT
# Insert of existing embedding ID: NOVICA
# Insert of existing embedding ID: NURI
# Insert of existing embedding ID: OGNJEN
# Insert of existing embedding ID: OGUZ
# Insert of existing embedding ID: OGUZHAN
# Insert of existing embedding ID: OKAN
# Insert of existing embedding ID: OKTAY
# Insert of existing embedding ID: OLEG
# Insert of existing embedding ID: OLEKSANDR
# Insert of existing embedding ID: OLIVER
# Insert of existing embedding ID: OLIVIER
# Insert of existing embedding ID: OMAR
# ...
# Insert of existing embedding ID: SOVAN
# Insert of existing embedding ID: CODA
# Insert of existing embedding ID: KRISTAN
# Insert of existing embedding ID: ANTUAN
# Insert of existing embedding ID: YAZEED
# Insert of existing embedding ID: SAMANTHA
# Insert of existing embedding ID: REYSE
# Insert of existing embedding ID: MAJD
# Insert of existing embedding ID: BRADEN
# Insert of existing embedding ID: KIRILL
# Insert of existing embedding ID: AKMAL
# Insert of existing embedding ID: WINTON
# Insert of existing embedding ID: TOMIYA
# Insert of existing embedding ID: PUTU
# Insert of existing embedding ID: KINA
# Insert of existing embedding ID: JAYSON
# Insert of existing embedding ID: RUBIN
# Insert of existing embedding ID: CORNELL
# Insert of existing embedding ID: RANDOLPH
# Insert of existing embedding ID: GREGORY
# Insert of existing embedding ID: KRISTON
# Insert of existing embedding ID: LUCKY
# Insert of existing embedding ID: ISRAEL
# Insert of existing embedding ID: JURY
# Insert of existing embedding ID: CANDICE
# Insert of existing embedding ID: JARDIN
# Insert of existing embedding ID: ROWAN
# Insert of existing embedding ID: NIVED
# Insert of existing embedding ID: DEEJAY
# Insert of existing embedding ID: CIEL
# Insert of existing embedding ID: CARMEN
# Insert of existing embedding ID: TRENTEN
# Insert of existing embedding ID: PASQUALINO
# Insert of existing embedding ID: MEIRION
# Insert of existing embedding ID: JO
# Insert of existing embedding ID: KAISEN
# Insert of existing embedding ID: OREST
# Insert of existing embedding ID: NILES
# Insert of existing embedding ID: STANISLAS
# Insert of existing embedding ID: APOSTOLOS
# Insert of existing embedding ID: EDWART
# Insert of existing embedding ID: DONNIE
# Insert of existing embedding ID: VESA
# Insert of existing embedding ID: KYREECE
# Insert of existing embedding ID: MORVEN
# Add of existing embedding ID: MATHANIEL
# Add of existing embedding ID: DAVIDJOHN
# Add of existing embedding ID: AVNI
# Add of existing embedding ID: JAMION
# Add of existing embedding ID: KAYN
# Add of existing embedding ID: JAMIE-LEIGH
# Add of existing embedding ID: NAYTE
# Add of existing embedding ID: BAILEY
# Add of existing embedding ID: GOKHAN
# Add of existing embedding ID: JAIRON
# Add of existing embedding ID: HENDRY
# Add of existing embedding ID: SHAKEEL
# Add of existing embedding ID: ELIAH
# Add of existing embedding ID: TRUEMAN
# Add of existing embedding ID: ELIJHA
# Add of existing embedding ID: TREIGH
# Add of existing embedding ID: ANNEMARIE
# Add of existing embedding ID: ANA
# Add of existing embedding ID: PARNELL
# Add of existing embedding ID: HIEN
# Add of existing embedding ID: JACOBUS
# Add of existing embedding ID: VASYL
# Add of existing embedding ID: CLAE
# Add of existing embedding ID: ERYK
# Add of existing embedding ID: DACE
# Add of existing embedding ID: PAYMAN
# Add of existing embedding ID: SAVAN
# Add of existing embedding ID: CHRISOPHER
# Add of existing embedding ID: TIAN
# Add of existing embedding ID: JOELL
# Add of existing embedding ID: TYLER-JAMES
# Add of existing embedding ID: TINY
# Add of existing embedding ID: ASHELY
# Add of existing embedding ID: RONIE
# Add of existing embedding ID: ELISSA
# Add of existing embedding ID: JAIR
# Add of existing embedding ID: JAGRAJ
# Add of existing embedding ID: RABIA
# Add of existing embedding ID: MARIJO
# Add of existing embedding ID: JASIAH
# Add of existing embedding ID: NIMRAT
# Add of existing embedding ID: KHIAN
# Add of existing embedding ID: KORBYN
# Add of existing embedding ID: ZAKARI
# Add of existing embedding ID: BONNEY
# Add of existing embedding ID: ABRIEL
# Add of existing embedding ID: LORRIN
# Add of existing embedding ID: MATAO
# Add of existing embedding ID: ANTONELLO
# Add of existing embedding ID: CHINMAY
# Add of existing embedding ID: ARISTIDES
# Add of existing embedding ID: JAYVEE
# Add of existing embedding ID: JAVED
# Add of existing embedding ID: MOSES
# Add of existing embedding ID: ALEKSEY
# Add of existing embedding ID: SOVAN
# Add of existing embedding ID: CODA
# Add of existing embedding ID: KRISTAN
# Add of existing embedding ID: ANTUAN
# Add of existing embedding ID: YAZEED
# Add of existing embedding ID: SAMANTHA
# Add of existing embedding ID: REYSE
# Add of existing embedding ID: MAJD
# Add of existing embedding ID: BRADEN
# Add of existing embedding ID: KIRILL
# Add of existing embedding ID: AKMAL
# Add of existing embedding ID: WINTON
# Add of existing embedding ID: TOMIYA
# Add of existing embedding ID: PUTU
# Add of existing embedding ID: KINA
# Add of existing embedding ID: JAYSON
# Add of existing embedding ID: RUBIN
# Add of existing embedding ID: CORNELL
# Add of existing embedding ID: RANDOLPH
# Add of existing embedding ID: GREGORY
# Add of existing embedding ID: KRISTON
# Add of existing embedding ID: LUCKY
# Add of existing embedding ID: ISRAEL
# Add of existing embedding ID: JURY
# Add of existing embedding ID: CANDICE
# Add of existing embedding ID: JARDIN
# Add of existing embedding ID: ROWAN
# Add of existing embedding ID: NIVED
# Add of existing embedding ID: DEEJAY
# Add of existing embedding ID: CIEL
# Add of existing embedding ID: CARMEN
# Add of existing embedding ID: TRENTEN
# Add of existing embedding ID: PASQUALINO
# Add of existing embedding ID: MEIRION
# Add of existing embedding ID: JO
# Add of existing embedding ID: KAISEN
# Add of existing embedding ID: OREST
# Add of existing embedding ID: NILES
# Add of existing embedding ID: STANISLAS
# Add of existing embedding ID: APOSTOLOS
# Add of existing embedding ID: EDWART
# Add of existing embedding ID: DONNIE
# Add of existing embedding ID: VESA
# Add of existing embedding ID: KYREECE
# Add of existing embedding ID: MORVEN
# Insert of existing embedding ID: CAILEN
# Insert of existing embedding ID: MAYON
# Insert of existing embedding ID: LAP
# Insert of existing embedding ID: STELLA
# Insert of existing embedding ID: KELANI
# Insert of existing embedding ID: YVETTE
# Insert of existing embedding ID: JULUIS
# Insert of existing embedding ID: SAKARI
# Insert of existing embedding ID: STEPHANIE
# Insert of existing embedding ID: GARNER
# Insert of existing embedding ID: KHIEM
# Insert of existing embedding ID: YEHUDA
# Insert of existing embedding ID: CABE
# Insert of existing embedding ID: VINEETH
# Insert of existing embedding ID: ERNIST
# Insert of existing embedding ID: KORIN
# Insert of existing embedding ID: BENITO
# Insert of existing embedding ID: TUCKER
# Insert of existing embedding ID: JAGEN
# Insert of existing embedding ID: AZZAM
# Insert of existing embedding ID: CY
# Insert of existing embedding ID: KIYO
# Insert of existing embedding ID: RISHAB
# Insert of existing embedding ID: CHRISTIANE
# Insert of existing embedding ID: KYME
# Insert of existing embedding ID: BLAIR
# Insert of existing embedding ID: ZEKI
# Insert of existing embedding ID: RASHAD
# Insert of existing embedding ID: SETTIMO
# Insert of existing embedding ID: NICHOLA
# Insert of existing embedding ID: FINNAN
# Insert of existing embedding ID: LUCY
# Insert of existing embedding ID: OLUWATIMILEHIN
# Insert of existing embedding ID: RUBY
# Insert of existing embedding ID: HAYNE
# Insert of existing embedding ID: ABED
# Insert of existing embedding ID: JERAMIAH
# Insert of existing embedding ID: LYNSAY
# Insert of existing embedding ID: RORY
# Insert of existing embedding ID: FARZAM
# Insert of existing embedding ID: BOEDY
# Insert of existing embedding ID: TALLEN
# Insert of existing embedding ID: TARRENCE
# Insert of existing embedding ID: RADENKO
# Insert of existing embedding ID: HESTON
# Insert of existing embedding ID: KERRIE-ANNE
# Insert of existing embedding ID: HANS-CHRISTIAN
# Insert of existing embedding ID: TALLYN
# Insert of existing embedding ID: SHAHRAM
# Insert of existing embedding ID: ARDEN
# Insert of existing embedding ID: TROOPER
# Insert of existing embedding ID: LENNIE
# Insert of existing embedding ID: JACOBB
# Insert of existing embedding ID: KYA
# Insert of existing embedding ID: JUSTUS
# Insert of existing embedding ID: TEAGAN
# Insert of existing embedding ID: DO
# Insert of existing embedding ID: SAMBHAV
# Insert of existing embedding ID: WINTER
# Insert of existing embedding ID: ALESIO
# Insert of existing embedding ID: MYKOLA
# Insert of existing embedding ID: COSTANTINO
# Insert of existing embedding ID: RADAN
# Insert of existing embedding ID: STACIE
# Insert of existing embedding ID: TAIVEN
# Insert of existing embedding ID: AUBURN
# Insert of existing embedding ID: STUART
# Insert of existing embedding ID: MYKAH
# Insert of existing embedding ID: JAROD
# Insert of existing embedding ID: BRODIN
# Insert of existing embedding ID: ERNESTO
# Insert of existing embedding ID: SUDJAI
# Insert of existing embedding ID: ZEIK
# Insert of existing embedding ID: ATEEB
# Insert of existing embedding ID: ARCHIE
# Insert of existing embedding ID: SHAGUN
# Insert of existing embedding ID: BLUE
# Insert of existing embedding ID: REM
# Insert of existing embedding ID: AINSLIE
# Insert of existing embedding ID: PADRIC
# Insert of existing embedding ID: MILIVOJ
# Insert of existing embedding ID: NOELINE
# Insert of existing embedding ID: EWEN
# Insert of existing embedding ID: JOHNNIE
# Insert of existing embedding ID: HAGAR
# Insert of existing embedding ID: TRACY-LEE
# Insert of existing embedding ID: BALEY
# Insert of existing embedding ID: SOKHA
# Insert of existing embedding ID: KISHAN
# Insert of existing embedding ID: GURVEER
# Insert of existing embedding ID: THEMISTOKLIS
# Insert of existing embedding ID: KHOEN
# Insert of existing embedding ID: KAVIAN
# Insert of existing embedding ID: SAVO
# Insert of existing embedding ID: KAELEN
# Insert of existing embedding ID: ARTIN
# Insert of existing embedding ID: GEOFFREY
# Insert of existing embedding ID: CONSTANTINOS
# Insert of existing embedding ID: TAKAI
# Insert of existing embedding ID: PIERROT
# Add of existing embedding ID: CAILEN
# Add of existing embedding ID: MAYON
# Add of existing embedding ID: LAP
# Add of existing embedding ID: STELLA
# Add of existing embedding ID: KELANI
# Add of existing embedding ID: YVETTE
# Add of existing embedding ID: JULUIS
# Add of existing embedding ID: SAKARI
# Add of existing embedding ID: STEPHANIE
# Add of existing embedding ID: GARNER
# Add of existing embedding ID: KHIEM
# Add of existing embedding ID: YEHUDA
# Add of existing embedding ID: CABE
# Add of existing embedding ID: VINEETH
# Add of existing embedding ID: ERNIST
# Add of existing embedding ID: KORIN
# Add of existing embedding ID: BENITO
# Add of existing embedding ID: TUCKER
# Add of existing embedding ID: JAGEN
# Add of existing embedding ID: AZZAM
# Add of existing embedding ID: CY
# Add of existing embedding ID: KIYO
# Add of existing embedding ID: RISHAB
# Add of existing embedding ID: CHRISTIANE
# Add of existing embedding ID: KYME
# Add of existing embedding ID: BLAIR
# Add of existing embedding ID: ZEKI
# Add of existing embedding ID: RASHAD
# Add of existing embedding ID: SETTIMO
# Add of existing embedding ID: NICHOLA
# Add of existing embedding ID: FINNAN
# Add of existing embedding ID: LUCY
# Add of existing embedding ID: OLUWATIMILEHIN
# Add of existing embedding ID: RUBY
# Add of existing embedding ID: HAYNE
# Add of existing embedding ID: ABED
# Add of existing embedding ID: JERAMIAH
# Add of existing embedding ID: LYNSAY
# Add of existing embedding ID: RORY
# Add of existing embedding ID: FARZAM
# Add of existing embedding ID: BOEDY
# Add of existing embedding ID: TALLEN
# Add of existing embedding ID: TARRENCE
# Add of existing embedding ID: RADENKO
# Add of existing embedding ID: HESTON
# Add of existing embedding ID: KERRIE-ANNE
# Add of existing embedding ID: HANS-CHRISTIAN
# Add of existing embedding ID: TALLYN
# Add of existing embedding ID: SHAHRAM
# Add of existing embedding ID: ARDEN
# Add of existing embedding ID: TROOPER
# Add of existing embedding ID: LENNIE
# Add of existing embedding ID: JACOBB
# Add of existing embedding ID: KYA
# Add of existing embedding ID: JUSTUS
# Add of existing embedding ID: TEAGAN
# Add of existing embedding ID: DO
# Add of existing embedding ID: SAMBHAV
# Add of existing embedding ID: WINTER
# Add of existing embedding ID: ALESIO
# Add of existing embedding ID: MYKOLA
# Add of existing embedding ID: COSTANTINO
# Add of existing embedding ID: RADAN
# Add of existing embedding ID: STACIE
# Add of existing embedding ID: TAIVEN
# Add of existing embedding ID: AUBURN
# Add of existing embedding ID: STUART
# Add of existing embedding ID: MYKAH
# Add of existing embedding ID: JAROD
# Add of existing embedding ID: BRODIN
# Add of existing embedding ID: ERNESTO
# Add of existing embedding ID: SUDJAI
# Add of existing embedding ID: ZEIK
# Add of existing embedding ID: ATEEB
# Add of existing embedding ID: ARCHIE
# Add of existing embedding ID: SHAGUN
# Add of existing embedding ID: BLUE
# Add of existing embedding ID: REM
# Add of existing embedding ID: AINSLIE
# Add of existing embedding ID: PADRIC
# Add of existing embedding ID: MILIVOJ
# Add of existing embedding ID: NOELINE
# Add of existing embedding ID: EWEN
# Add of existing embedding ID: JOHNNIE
# Add of existing embedding ID: HAGAR
# Add of existing embedding ID: TRACY-LEE
# Add of existing embedding ID: BALEY
# Add of existing embedding ID: SOKHA
# Add of existing embedding ID: KISHAN
# Add of existing embedding ID: GURVEER
# Add of existing embedding ID: THEMISTOKLIS
# Add of existing embedding ID: KHOEN
# Add of existing embedding ID: KAVIAN
# Add of existing embedding ID: SAVO
# Add of existing embedding ID: KAELEN
# Add of existing embedding ID: ARTIN
# Add of existing embedding ID: GEOFFREY
# Add of existing embedding ID: CONSTANTINOS
# Add of existing embedding ID: TAKAI
# Add of existing embedding ID: PIERROT
# Insert of existing embedding ID: KORY
# Insert of existing embedding ID: NAWAF
# Insert of existing embedding ID: LENN
# Insert of existing embedding ID: SRIYAN
# Insert of existing embedding ID: PATRICH
# Insert of existing embedding ID: DYAR
# Insert of existing embedding ID: LEONE
# Insert of existing embedding ID: DENIM
# Insert of existing embedding ID: NADA
# Insert of existing embedding ID: DAMIE
# Insert of existing embedding ID: CAI
# Insert of existing embedding ID: JAQWAN
# Insert of existing embedding ID: JAY-JAY
# Insert of existing embedding ID: TAYGEN
# Insert of existing embedding ID: JULIANO
# Insert of existing embedding ID: RYLEIGH
# Insert of existing embedding ID: EDER
# Insert of existing embedding ID: KALMAN
# Insert of existing embedding ID: WINAND
# Insert of existing embedding ID: AGIM
# Insert of existing embedding ID: SHANNEN
# Insert of existing embedding ID: LAMA
# Insert of existing embedding ID: DARDI
# Insert of existing embedding ID: DAVINDER
# Insert of existing embedding ID: NATAN
# Insert of existing embedding ID: BEXLEY
# Insert of existing embedding ID: RYON
# Insert of existing embedding ID: TRUDI
# Insert of existing embedding ID: ARMAND
# Insert of existing embedding ID: DENZELL
# Insert of existing embedding ID: STYLES
# Insert of existing embedding ID: DEDAN
# Insert of existing embedding ID: SOKRATIS
# Insert of existing embedding ID: BRYAN
# Insert of existing embedding ID: LAWYER
# Insert of existing embedding ID: VLADAS
# Insert of existing embedding ID: STEPAN
# Insert of existing embedding ID: MAKIYAH
# Insert of existing embedding ID: MOHAMED
# Insert of existing embedding ID: ZAYDYN
# Insert of existing embedding ID: DEMETRE
# Insert of existing embedding ID: ESSAM
# Insert of existing embedding ID: SEUMAS
# Insert of existing embedding ID: ROCCO
# Insert of existing embedding ID: DETLEF
# Insert of existing embedding ID: KIAAN
# Insert of existing embedding ID: CHILLI
# Insert of existing embedding ID: BRYNE
# Insert of existing embedding ID: WAYDE
# Insert of existing embedding ID: MATTIA
# Insert of existing embedding ID: NGOR
# Insert of existing embedding ID: APOLLON
# Insert of existing embedding ID: JOSCELIN
# Insert of existing embedding ID: CAELAN
# Insert of existing embedding ID: FELIPE
# Insert of existing embedding ID: HENDRICK
# Insert of existing embedding ID: RAYMAN
# Insert of existing embedding ID: JOSCHUA
# Insert of existing embedding ID: PADRAIC
# Insert of existing embedding ID: HARRIE
# Insert of existing embedding ID: SEMISI
# Insert of existing embedding ID: MARLEY
# Insert of existing embedding ID: SHAUNAK
# Insert of existing embedding ID: THADDEAUS
# Insert of existing embedding ID: NICOLINO
# Insert of existing embedding ID: MUSIE
# Insert of existing embedding ID: OSKA
# Insert of existing embedding ID: KYLLIE
# Insert of existing embedding ID: ANAN
# Insert of existing embedding ID: SHASHI

# %%
print(collection.count())
# Out:
# 23007

# %%
import chromadb
from chromadb.utils import embedding_functions

def query_baby_names(query_text, n_results=50):
    # Initialize Chroma client and get the collection
    embedding_function = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="all-MiniLM-L6-v2")
    collection = get_babynames_collection()

    # Query the collection
    results = collection.query(
        query_texts=[query_text],
        n_results=n_results,
        include=["documents", "metadatas", "distances"],
        where={"sex": "Male"} 
    )

    # Process and print results
    print(f"Top {n_results} results for query: '{query_text}'\n")
    for i, (doc, metadata, distance) in enumerate(zip(results['documents'][0], results['metadatas'][0], results['distances'][0]), 1):
        print(f"{i}. Distance: {distance:.4f}")
        print(f"   {doc}")

    return results

# Example usage
query_text = "intentional, punctual, timely, english, german, irish"
results = query_baby_names(query_text)
# Out:
# Top 50 results for query: 'intentional, punctual, timely, english, german, irish'
#
# 1. Distance: 1.1560
#    Name: EION|Sex: Male|Nation: Irish|Meaning: God is gracious
# 2. Distance: 1.1689
#    Name: DEVIN|Sex: Male|Nation: Irish|Meaning: Poet or bard
# 3. Distance: 1.1909
#    Name: ERNIST|Sex: Male|Nation: German|Meaning: Earnest or serious
# 4. Distance: 1.1931
#    Name: FINNEAN|Sex: Male|Nation: Irish|Meaning: Fair or white
# 5. Distance: 1.2037
#    Name: EON|Sex: Male|Nation: Irish|Meaning: God is gracious
# 6. Distance: 1.2041
#    Name: FINN|Sex: Male|Nation: Irish, Scandinavian|Meaning: Fair, white, or blessed
# 7. Distance: 1.2108
#    Name: EIAN|Sex: Male|Nation: Irish|Meaning: God is gracious
# 8. Distance: 1.2181
#    Name: SINCERE|Sex: Male|Nation: English|Meaning: Genuine, honest, or truthful
# 9. Distance: 1.2193
#    Name: EAN|Sex: Male|Nation: Irish|Meaning: God is gracious
# 10. Distance: 1.2194
#    Name: SHONE|Sex: Male|Nation: Irish|Meaning: God is gracious
# 11. Distance: 1.2273
#    Name: ALAN|Sex: Male|Nation: English, Irish, French|Meaning: Handsome, cheerful
# 12. Distance: 1.2306
#    Name: SHEAN|Sex: Male|Nation: Irish|Meaning: God is gracious
# 13. Distance: 1.2429
#    Name: FINNIAN|Sex: Male|Nation: Irish|Meaning: Descendant of Fionn, meaning 'fair' or 'white'
# 14. Distance: 1.2443
#    Name: COLM|Sex: Male|Nation: Irish|Meaning: Dove
# 15. Distance: 1.2443
#    Name: EARNEST|Sex: Male|Nation: English|Meaning: Serious, sincere, or determined
# 16. Distance: 1.2446
#    Name: TEAGUE|Sex: Male|Nation: Irish|Meaning: Poet
# 17. Distance: 1.2448
#    Name: RHYTHM|Sex: Male|Nation: English|Meaning: A strong, regular, repeated pattern of movement or sound
# 18. Distance: 1.2458
#    Name: EMMET|Sex: Male|Nation: Irish|Meaning: Universal
# 19. Distance: 1.2467
#    Name: KEON|Sex: Male|Nation: Irish|Meaning: God is gracious
# 20. Distance: 1.2471
#    Name: EOIN|Sex: Male|Nation: Irish|Meaning: God is gracious
# 21. Distance: 1.2519
#    Name: FARELL|Sex: Male|Nation: Irish|Meaning: brave or courageous
# 22. Distance: 1.2557
#    Name: GAËL|Sex: Male|Nation: French|Meaning: Generous
# 23. Distance: 1.2646
#    Name: KEVAN|Sex: Male|Nation: Irish|Meaning: Handsome, beloved
# 24. Distance: 1.2654
#    Name: EVIN|Sex: Male|Nation: Irish|Meaning: God is gracious
# 25. Distance: 1.2663
#    Name: FINNBARR|Sex: Male|Nation: Irish|Meaning: Fair-haired or white
# 26. Distance: 1.2703
#    Name: TAIT|Sex: Male|Nation: Scottish|Meaning: cheerful or lively
# 27. Distance: 1.2704
#    Name: FIONN|Sex: Male|Nation: Irish|Meaning: fair or white
# 28. Distance: 1.2708
#    Name: REAL|Sex: Male|Nation: English|Meaning: Genuine, true, or authentic
# 29. Distance: 1.2741
#    Name: ALLAN|Sex: Male|Nation: English, Scottish|Meaning: Handsome, cheerful
# 30. Distance: 1.2753
#    Name: AIMABLE|Sex: Male|Nation: French|Meaning: lovable or kind
# 31. Distance: 1.2769
#    Name: BRION|Sex: Male|Nation: Irish|Meaning: Noble; strong
# 32. Distance: 1.2770
#    Name: QUIN|Sex: Male|Nation: Irish|Meaning: Wise
# 33. Distance: 1.2783
#    Name: HUGH|Sex: Male|Nation: English, Irish, French|Meaning: Heart, mind, or spirit
# 34. Distance: 1.2793
#    Name: AWEN|Sex: Male|Nation: Welsh|Meaning: Inspiration or poetic muse
# 35. Distance: 1.2814
#    Name: IAIN|Sex: Male|Nation: Scottish|Meaning: God is gracious
# 36. Distance: 1.2828
#    Name: PARFAIT|Sex: Male|Nation: French|Meaning: perfect
# 37. Distance: 1.2835
#    Name: FINNAN|Sex: Male|Nation: Irish|Meaning: Little fair one
# 38. Distance: 1.2841
#    Name: BRECCAN|Sex: Male|Nation: Irish|Meaning: Freckled or speckled
# 39. Distance: 1.2851
#    Name: CIAN|Sex: Male|Nation: Irish|Meaning: Ancient; God is gracious
# 40. Distance: 1.2851
#    Name: SEAN|Sex: Male|Nation: Irish|Meaning: God is gracious
# 41. Distance: 1.2859
#    Name: ADEEN|Sex: Male|Nation: Irish|Meaning: Little fire
# 42. Distance: 1.2895
#    Name: IEUAN|Sex: Male|Nation: Welsh|Meaning: God is gracious
# 43. Distance: 1.2896
#    Name: HANNS|Sex: Male|Nation: German|Meaning: God is gracious
# 44. Distance: 1.2919
#    Name: FARRELL|Sex: Male|Nation: Irish|Meaning: brave man
# 45. Distance: 1.2923
#    Name: SHANE|Sex: Male|Nation: Irish|Meaning: God is gracious
# 46. Distance: 1.2940
#    Name: KEIAN|Sex: Male|Nation: Irish|Meaning: Ancient or God is gracious
# 47. Distance: 1.2941
#    Name: DAIR|Sex: Male|Nation: Irish|Meaning: Slight or small
# 48. Distance: 1.2943
#    Name: DOYLE|Sex: Male|Nation: Irish|Meaning: Dark haired
# 49. Distance: 1.2993
#    Name: TRUE|Sex: Male|Nation: English|Meaning: True, genuine, or faithful
# 50. Distance: 1.2994
#    Name: IRA|Sex: Male|Nation: Hebrew|Meaning: Watchful or vigilant

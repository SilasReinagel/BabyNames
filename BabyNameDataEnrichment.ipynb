# %%
# Step 1: LangChain and OpenAI Integration

# Import necessary libraries
import os
import json
from langchain_openai import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.output_parsers import StructuredOutputParser, ResponseSchema

# Initialize the OpenAI model
llm = ChatOpenAI(model_name="gpt-4o-mini", temperature=0)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
# Define the response schemas
response_schemas = [
    ResponseSchema(name="nationality_origin", description="The likely nationality origin of the name"),
    ResponseSchema(name="meaning", description="The meaning or definition of the name. Include all key concepts of the meaning (but NOT the history), and at least a short paragraph of meaning explanation"),
]

# Create the output parser
output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# Create a prompt template
prompt = PromptTemplate(
    input_variables=["name"],
    partial_variables={"format_instructions": output_parser.get_format_instructions()},
    template="""Provide information about the baby name {name}. Include:
1) Likely nationality origin
2) Name meaning or definition

{format_instructions}"""
)

# Create an LLMChain
name_info_chain = LLMChain(llm=llm, prompt=prompt)

# Function to process the result and return JSON
def get_name_info(name):
    result = name_info_chain.run(name)
    parsed_result = output_parser.parse(result)
    return json.dumps(parsed_result, indent=2)

# Test the chain
test_name = "Emma"
result = get_name_info(test_name)
print(result)
# Out:
# {
#   "nationality_origin": "English, German",
#   "meaning": "The name Emma is derived from the Germanic word 'ermen,' which means 'whole' or 'universal.' It signifies completeness and is often associated with strength and beauty. In modern usage, Emma is a popular name that conveys a sense of elegance and charm. The name has been widely embraced across various cultures and languages, making it a timeless choice for many parents."
# }

# %%
import pandas as pd

def process_baby_names_data(input_file='./data/all-names.csv', output_file='./data/all-names-enriched.csv'):
    df = pd.read_csv(input_file)
    
    # Add new columns for nationality and meaning
    df['nationality'] = ''
    df['meaning'] = ''
    
    # Ensure the DataFrame has a header
    df.columns.name = None
    
    # Write the processed data to a new CSV file with header
    df.to_csv(output_file, index=False)
    
    print(f"Processed data written to {output_file}")
    
    # Return a summary of the data
    return {
        'total_names': len(df),
    }

# Example usage
summary = process_baby_names_data()
print("Data Summary:", summary)
# Out:
# Processed data written to ./data/all-names-enriched.csv
# Data Summary: {'total_names': 97697}

# %%
import pandas as pd

def filter_rare_names(file_path='./data/all-names-enriched.csv', min_occurrences=10):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Store the original number of names
    original_count = len(df)
    
    # Filter out names with 10 or fewer occurrences
    df_filtered = df[df['n_sum'] > min_occurrences]
    
    # Store the new number of names
    filtered_count = len(df_filtered)
    
    # Write the filtered data back to the CSV file
    # df_filtered.to_csv(file_path, index=False)
    
    # Calculate the number of names removed
    removed_count = original_count - filtered_count
    
    print(f"Filtered data written back to {file_path}")
    print(f"Names removed: {removed_count}")
    print(f"Names remaining: {filtered_count}")
    
    # Return a summary of the operation
    return {
        'original_count': original_count,
        'filtered_count': filtered_count,
        'removed_count': removed_count,
        'removal_percentage': (removed_count / original_count) * 100
    }

# Example usage
summary = filter_rare_names()
print("\nOperation Summary:")
for key, value in summary.items():
    print(f"{key}: {value}")
# Out:
# Filtered data written back to ./data/all-names-enriched.csv
# Names removed: 23730
# Names remaining: 73967
#
# Operation Summary:
# original_count: 97697
# filtered_count: 73967
# removed_count: 23730
# removal_percentage: 24.289384525625145

# %%
# Non-Debug Printing Version

import pandas as pd
from tqdm import tqdm
from langchain_openai import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.output_parsers import StructuredOutputParser, ResponseSchema

def enrich_baby_names_data(file='./data/all-names-enriched.csv', limit=1000):
    # Load the data
    df = pd.read_csv(file)
    print(f"Loaded {len(df)} names from {file}")
    
    # Initialize the OpenAI model
    llm = ChatOpenAI(model_name="gpt-4o-mini", temperature=0)
    
    # Define the response schemas
    response_schemas = [
        ResponseSchema(name="nationality", description="The likely nationality origin of the name"),
        ResponseSchema(name="meaning", description="The meaning or definition of the name. Include all key definition concepts of the meaning (but NOT the history), and at least a short paragraph of meaning explanation"),
    ]
    
    # Create the output parser
    output_parser = StructuredOutputParser.from_response_schemas(response_schemas)
    
    # Create a prompt template
    prompt = PromptTemplate(
        input_variables=["name"],
        partial_variables={"format_instructions": output_parser.get_format_instructions()},
        template="""Provide information about the baby name {name}. Include:
    1) Likely nationality origin
    2) The meaning or definition of the name. Include all key definition concepts of the meaning (but NOT the history), and at least a short paragraph of meaning explanation
    {format_instructions}
    I will tip you $1000 if you follow these instructions.
    """
    )
    
    # Create an LLMChain
    name_info_chain = LLMChain(llm=llm, prompt=prompt)
    
    # Function to get name info
    def get_name_info(name):
        result = name_info_chain.run(name)
        try:
            parsed_result = output_parser.parse(result)
            return parsed_result
        except Exception as e:
            print(f"Error processing {name}: {e}")
            return None
    
    # Process each name, limited to 'limit' number of records
    names_to_process = df.loc[(df['meaning'].isna()) & (df['n_sum'] > 10), 'name'].head(limit)
    
    for name in tqdm(names_to_process, desc="Processing names"):
        new_data = get_name_info(name)
        if new_data:
            df.loc[df['name'] == name, ['nationality', 'meaning']] = [new_data['nationality'], new_data['meaning']]
            # Save the entire DataFrame after updating this row
            df.to_csv(file, index=False)
    
    print(f"Finished processing. Final data written to {file}")
    
    # Return a summary of the data
    summary = {
        'total_names': len(df),
        'processed_names': df['meaning'].notna().sum(),
        'unique_nationalities': df['nationality'].nunique(),
    }
    print("Data Summary:", summary)
    return summary

# Example usage
summary = enrich_baby_names_data(limit=100000)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# Loaded 17574 names from ./data/all-names-enriched.csv
# Processing names:   0%|                                                                                                                                                | 0/1669 [00:00<?, ?it/s]/opt/anaconda3/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# Processing names:   3%|████▎                                                                                                                                  | 54/1669 [01:31<41:57,  1.56s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:   7%|████████▉                                                                                                                             | 111/1669 [03:02<36:08,  1.39s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:   7%|█████████▏                                                                                                                            | 114/1669 [03:07<38:46,  1.50s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:   7%|█████████▎                                                                                                                            | 116/1669 [03:10<42:11,  1.63s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:   7%|█████████▍                                                                                                                            | 118/1669 [03:14<43:27,  1.68s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  10%|█████████████▍                                                                                                                      | 170/1669 [04:46<1:02:01,  2.48s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  10%|█████████████▊                                                                                                                        | 172/1669 [04:50<52:29,  2.10s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  10%|██████████████                                                                                                                        | 175/1669 [04:55<47:23,  1.90s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  14%|██████████████████▋                                                                                                                   | 233/1669 [06:27<42:42,  1.78s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  14%|██████████████████▉                                                                                                                   | 236/1669 [06:31<37:04,  1.55s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  14%|███████████████████▏                                                                                                                  | 239/1669 [06:36<38:46,  1.63s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  18%|███████████████████████▊                                                                                                              | 297/1669 [08:07<36:58,  1.62s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  18%|████████████████████████                                                                                                              | 300/1669 [08:12<33:30,  1.47s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  18%|████████████████████████▎                                                                                                             | 303/1669 [08:17<38:00,  1.67s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  22%|████████████████████████████▉                                                                                                         | 361/1669 [09:49<32:52,  1.51s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  22%|█████████████████████████████▏                                                                                                        | 363/1669 [09:52<33:09,  1.52s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  22%|█████████████████████████████▍                                                                                                        | 367/1669 [09:58<31:15,  1.44s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  25%|█████████████████████████████████▋                                                                                                    | 419/1669 [11:32<45:07,  2.17s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  26%|███████████████████████████████████▍                                                                                                  | 441/1669 [12:05<30:18,  1.48s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  27%|███████████████████████████████████▌                                                                                                  | 443/1669 [12:09<35:40,  1.75s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  27%|███████████████████████████████████▊                                                                                                  | 446/1669 [12:14<31:45,  1.56s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  30%|███████████████████████████████████████▊                                                                                              | 496/1669 [13:45<47:25,  2.43s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  33%|████████████████████████████████████████████▎                                                                                         | 552/1669 [15:17<28:16,  1.52s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  33%|████████████████████████████████████████████▌                                                                                         | 555/1669 [15:22<31:34,  1.70s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  33%|████████████████████████████████████████████▊                                                                                         | 558/1669 [15:26<30:40,  1.66s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  34%|████████████████████████████████████████████▉                                                                                         | 560/1669 [15:30<29:40,  1.61s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  37%|█████████████████████████████████████████████████▊                                                                                    | 621/1669 [17:02<27:09,  1.56s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithError("Failed to POST https://api.smith.langchain.com/runs/batch in LangSmith API. ('Connection broken: IncompleteRead(0 bytes read, 55 more expected)', IncompleteRead(0 bytes read, 55 more expected))\n")
# Processing names:  37%|██████████████████████████████████████████████████                                                                                    | 624/1669 [17:07<25:58,  1.49s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  40%|█████████████████████████████████████████████████████▊                                                                                | 671/1669 [18:39<25:35,  1.54s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  40%|██████████████████████████████████████████████████████                                                                                | 673/1669 [18:42<26:43,  1.61s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  41%|██████████████████████████████████████████████████████▎                                                                               | 676/1669 [18:47<26:16,  1.59s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  44%|██████████████████████████████████████████████████████████▌                                                                           | 729/1669 [20:20<25:15,  1.61s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  45%|████████████████████████████████████████████████████████████▏                                                                         | 749/1669 [20:52<23:07,  1.51s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  47%|███████████████████████████████████████████████████████████████▏                                                                      | 787/1669 [21:54<24:16,  1.65s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  47%|███████████████████████████████████████████████████████████████▌                                                                      | 791/1669 [22:00<21:38,  1.48s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  51%|███████████████████████████████████████████████████████████████████▊                                                                  | 845/1669 [23:32<26:57,  1.96s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  51%|████████████████████████████████████████████████████████████████████                                                                  | 848/1669 [23:37<22:22,  1.64s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  51%|████████████████████████████████████████████████████████████████████▍                                                                 | 852/1669 [23:43<22:07,  1.63s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  51%|████████████████████████████████████████████████████████████████████▌                                                                 | 854/1669 [23:46<21:20,  1.57s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  55%|█████████████████████████████████████████████████████████████████████████▏                                                            | 911/1669 [25:18<21:54,  1.73s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  58%|█████████████████████████████████████████████████████████████████████████████▌                                                        | 966/1669 [26:50<20:43,  1.77s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  58%|█████████████████████████████████████████████████████████████████████████████▊                                                        | 969/1669 [26:54<16:55,  1.45s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  58%|██████████████████████████████████████████████████████████████████████████████                                                        | 972/1669 [26:58<17:57,  1.55s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  58%|██████████████████████████████████████████████████████████████████████████████▎                                                       | 975/1669 [27:03<16:58,  1.47s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  59%|██████████████████████████████████████████████████████████████████████████████▌                                                       | 978/1669 [27:07<15:53,  1.38s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  62%|██████████████████████████████████████████████████████████████████████████████████▋                                                  | 1038/1669 [28:39<16:19,  1.55s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  62%|██████████████████████████████████████████████████████████████████████████████████▉                                                  | 1041/1669 [28:43<16:27,  1.57s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  62%|███████████████████████████████████████████████████████████████████████████████████                                                  | 1043/1669 [28:47<17:49,  1.71s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  64%|████████████████████████████████████████████████████████████████████████████████████▊                                                | 1064/1669 [29:19<14:06,  1.40s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  67%|████████████████████████████████████████████████████████████████████████████████████████▉                                            | 1116/1669 [30:51<15:49,  1.72s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  67%|█████████████████████████████████████████████████████████████████████████████████████████▏                                           | 1119/1669 [30:56<15:00,  1.64s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  67%|█████████████████████████████████████████████████████████████████████████████████████████▎                                           | 1121/1669 [30:59<15:13,  1.67s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  71%|█████████████████████████████████████████████████████████████████████████████████████████████▊                                       | 1178/1669 [32:31<15:57,  1.95s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  71%|██████████████████████████████████████████████████████████████████████████████████████████████                                       | 1181/1669 [32:36<13:55,  1.71s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  71%|██████████████████████████████████████████████████████████████████████████████████████████████▎                                      | 1183/1669 [32:39<12:44,  1.57s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  74%|██████████████████████████████████████████████████████████████████████████████████████████████████▌                                  | 1237/1669 [34:09<11:48,  1.64s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  74%|██████████████████████████████████████████████████████████████████████████████████████████████████▊                                  | 1240/1669 [34:15<12:52,  1.80s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  74%|██████████████████████████████████████████████████████████████████████████████████████████████████▉                                  | 1242/1669 [34:18<12:09,  1.71s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  78%|███████████████████████████████████████████████████████████████████████████████████████████████████████▎                             | 1297/1669 [35:52<08:28,  1.37s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  80%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▌                          | 1337/1669 [36:55<10:09,  1.84s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  80%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▊                          | 1340/1669 [36:59<08:35,  1.57s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  80%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▉                          | 1342/1669 [37:02<08:27,  1.55s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  81%|███████████████████████████████████████████████████████████████████████████████████████████████████████████                          | 1344/1669 [37:08<10:41,  1.97s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                     | 1405/1669 [38:41<07:19,  1.67s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                   | 1422/1669 [40:12<06:22,  1.55s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                   | 1425/1669 [40:16<06:07,  1.50s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  86%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                   | 1428/1669 [40:21<06:06,  1.52s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎              | 1484/1669 [41:52<04:34,  1.48s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍              | 1487/1669 [41:56<04:21,  1.44s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋              | 1490/1669 [42:00<04:05,  1.37s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍            | 1511/1669 [42:33<03:53,  1.48s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋            | 1514/1669 [42:38<03:54,  1.51s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████        | 1569/1669 [44:09<02:48,  1.68s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names:  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍      | 1587/1669 [44:43<02:16,  1.66s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋      | 1590/1669 [44:46<01:53,  1.44s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊      | 1592/1669 [44:51<02:29,  1.94s/it]Failed to batch ingest runs: LangSmithConnectionError('Connection error caused failure to POST https://api.smith.langchain.com/runs/batch  in LangSmith API. Please confirm your internet connection.. SSLError(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /runs/batch (Caused by SSLError(SSLEOFError(8, \'EOF occurred in violation of protocol (_ssl.c:2406)\')))"))')
# Processing names:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 1646/1669 [46:23<00:34,  1.48s/it]Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Processing names: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1669/1669 [46:59<00:00,  1.69s/it]
# Finished processing. Final data written to ./data/all-names-enriched.csv
# Data Summary: {'total_names': 17574, 'processed_names': 17574, 'unique_nationalities': 708}
